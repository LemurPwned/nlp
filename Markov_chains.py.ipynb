# %%
import numpy as np 
import os 
import re
from collections import Counter

# %%
test_dir = './lab7/test'
def list_autors_and_books(directory):
    authors = {}
    for item in os.listdir(directory):
        author, _ = item.split('-')
        if author not in authors:
            authors[author] = []
        authors[author].append(item)
    test_set, train_set = [], []
    for author in authors:
        if len(authors[author]) < 2:
            raise ValueError("Insufficient number of books to create test set!")
        if len(authors[author]) > 7:
            for book in authors[author][:3]:
                test_set.append((author, book))
            for book in authors[author][3:8]:
                train_set.append((author, book))
        else:
            test_set.append((author, authors[author][0]))
            for book in authors[author][1:8]:
                train_set.append((author, book))
    return authors, test_set, train_set

# %% [markdown]
# if dict is [word_n][word_n-1, word_n-2, ...] then it's better results than
# [word_n-1, word_n-2, ...][word]
#
# P(w_i | w_i-1, w_i-2 ...) = C(w_i, w_i-1, w_i-2...)/C(w_i-1, w_i-2...)

# %%
authors, test_set, train_set = list_autors_and_books(test_dir)
for author in authors:
    print(f"{author}, books: {len(authors[author])}")
print(test_set)
# Out:
# Philip_K_Dick_, books: 7
# Terry_Pratchett_, books: 19
# Stephen_King_, books: 6
# Sapkowski_Andrzej_, books: 5
# Tolkien_J_R_R_, books: 3
# Lem_Stanislaw_, books: 8
# [('Philip_K_Dick_', 'Philip_K_Dick_-_Kosmiczne_marionetki.txt'), ('Terry_Pratchett_', 'Terry_Pratchett_-_Czarodzicielstwo.txt'), ('Terry_Pratchett_', 'Terry_Pratchett_-_Kosiarz.txt'), ('Terry_Pratchett_', 'Terry_Pratchett_-_Piramidy.txt'), ('Stephen_King_', 'Stephen_King_-_Marzenia_i_Koszmary_2.txt'), ('Sapkowski_Andrzej_', 'Sapkowski_Andrzej_-_Okruch_lodu.txt'), ('Tolkien_J_R_R_', 'Tolkien_J_R_R_-_O_Tuorze_i_jego_przybyciu_do_Gondolinu.txt'), ('Lem_Stanislaw_', 'Lem_Stanislaw_-_Summa_Technologiae.txt'), ('Lem_Stanislaw_', 'Lem_Stanislaw_-_Bajki_robotow.txt'), ('Lem_Stanislaw_', 'Lem_Stanislaw_-_Niezwyciezony.txt')]

# %%
def build_markov_chain(markov, text_sample, order=4):
    words = re.findall(r'\w+', open(text_sample, 'r').read().lower())
    for i in range(len(words)-order):
        ngram = words[i:i+order]
        x = ', '.join(ngram[:-1])
        if x not in markov:
            markov[x] = Counter()
        markov[x][ngram[-1]] += 1
        markov[x]['#sum'] += 1
        if ngram[-2] not in markov:
            markov[ngram[-2]] = Counter()
        markov[ngram[-2]][ngram[-1]] += 1
        markov[ngram[-2]]['#sum'] += 1
    return markov
markov = {}
build_markov_chain(markov, os.path.join(test_dir, 'Philip_K_Dick_-_Kosmiczne_marionetki.txt'))
# Out:
# {'philip, k, dick': Counter({'kosmiczne': 1, '#sum': 1}),
#  'dick': Counter({'kosmiczne': 1, '#sum': 1}),
#  'k, dick, kosmiczne': Counter({'marionetki': 1, '#sum': 1}),
#  'kosmiczne': Counter({'marionetki': 1, '#sum': 2, 'bieguny': 1}),
#  'dick, kosmiczne, marionetki': Counter({'przełożyła': 1, '#sum': 1}),
#  'marionetki': Counter({'przełożyła': 1, '#sum': 1}),
#  'kosmiczne, marionetki, przełożyła': Counter({'jadwiga': 1, '#sum': 1}),
#  'przełożyła': Counter({'jadwiga': 1, '#sum': 1}),
#  'marionetki, przełożyła, jadwiga': Counter({'andruszkiewicz': 1, '#sum': 1}),
#  'jadwiga': Counter({'andruszkiewicz': 1, '#sum': 1}),
#  'przełożyła, jadwiga, andruszkiewicz': Counter({'fiejtek': 1, '#sum': 1}),
#  'andruszkiewicz': Counter({'fiejtek': 1, '#sum': 1}),
#  'jadwiga, andruszkiewicz, fiejtek': Counter({'mojej': 1, '#sum': 1}),
#  'fiejtek': Counter({'mojej': 1, '#sum': 1}),
#  'andruszkiewicz, fiejtek, mojej': Counter({'siostrze': 1, '#sum': 1}),
#  'mojej': Counter({'siostrze': 1,
#           '#sum': 5,
#           'skale': 1,
#           'gliny': 1,
#           'kryjówki': 1,
#           'córce': 1}),
#  'fiejtek, mojej, siostrze': Counter({'fran': 1, '#sum': 1}),
#  'siostrze': Counter({'fran': 1, '#sum': 1}),
#  'mojej, siostrze, fran': Counter({'gibson': 1, '#sum': 1}),
#  'fran': Counter({'gibson': 1, '#sum': 1}),
#  'siostrze, fran, gibson': Counter({'z': 1, '#sum': 1}),
#  'gibson': Counter({'z': 1, '#sum': 1}),
#  'fran, gibson, z': Counter({'zachwytem': 1, '#sum': 1}),
#  'z': Counter({'zachwytem': 1,
#           '#sum': 513,
#           'dala': 3,
#           'rękoma': 3,
#           'podziwem': 1,
#           'jego': 5,
#           'ociąganiem': 1,
#           'czułością': 2,
#           'powrotem': 23,
#           'trudem': 16,
#           'wyraźnym': 1,
#           'nich': 13,
#           'artykułami': 2,
#           'głównej': 1,
#           'niej': 12,
#           'twojego': 1,
#           'nogą': 1,
#           'gór': 1,
#           'podniecenia': 2,
#           'wosku': 1,
#           'towarami': 4,
#           'łuszczącą': 1,
#           'nawozami': 1,
#           'niezadowoleniem': 2,
#           'szerokimi': 1,
#           'czasów': 2,
#           'panią': 2,
#           'lękiem': 1,
#           'jedzeniem': 1,
#           'tyłu': 2,
#           'jajkami': 1,
#           'obawą': 1,
#           'jakąś': 1,
#           'rozpaczą': 1,
#           'desek': 1,
#           'rozpiętym': 1,
#           'hukiem': 4,
#           'ulgą': 4,
#           'października': 1,
#           'nim': 5,
#           'wirującej': 1,
#           'dziką': 1,
#           'wyraźną': 1,
#           'niepokojem': 4,
#           'millgate': 3,
#           'pełnym': 1,
#           'nami': 3,
#           'peterem': 1,
#           'dużym': 1,
#           'buta': 1,
#           'piskiem': 2,
#           'nieznajomym': 1,
#           'obcym': 1,
#           'rąk': 4,
#           'nowego': 5,
#           'panem': 4,
#           'pokoju': 4,
#           'wielu': 1,
#           'ogromnymi': 1,
#           'małego': 1,
#           'południa': 1,
#           'ciekawością': 2,
#           'miejsca': 6,
#           'tego': 6,
#           'kolei': 2,
#           'ręki': 2,
#           'rozchylonymi': 3,
#           'włosami': 2,
#           'odpowiednio': 1,
#           'gliną': 1,
#           'wędrowców': 4,
#           'całej': 3,
#           'efektu': 1,
#           'oczu': 2,
#           'czerwonymi': 1,
#           'pająkami': 1,
#           'powodu': 2,
#           'ćmami': 1,
#           'pająków': 1,
#           'podręcznego': 1,
#           'wężami': 1,
#           'jakiegoś': 2,
#           'własnej': 1,
#           'zatokami': 2,
#           'boku': 2,
#           'której': 2,
#           'zainteresowaniem': 3,
#           'wrażenia': 1,
#           'całą': 2,
#           'maleńkiego': 1,
#           'pewnością': 4,
#           'tym': 10,
#           'całym': 1,
#           'tedem': 2,
#           'panną': 1,
#           'moimi': 1,
#           'miasta': 2,
#           'czym': 2,
#           'rozłożonymi': 1,
#           'uśmiechem': 1,
#           'siebie': 2,
#           'końca': 1,
#           'jakim': 1,
#           'domu': 1,
#           'budynku': 2,
#           'trzech': 1,
#           'mojej': 2,
#           'zewnątrz': 3,
#           'faktem': 1,
#           'zupełnie': 1,
#           'dżinsów': 1,
#           'liścia': 1,
#           'hotelem': 1,
#           'niesmakiem': 3,
#           'nadzieją': 3,
#           'przodu': 4,
#           'tymi': 3,
#           'kryjówki': 2,
#           'doktorem': 1,
#           'kieszeni': 3,
#           'pasją': 1,
#           'wyższością': 1,
#           'początku': 4,
#           'niebem': 1,
#           'doliny': 2,
#           'jednego': 2,
#           'jej': 2,
#           'postaci': 1,
#           'samochodu': 1,
#           'jednej': 3,
#           'drugiej': 2,
#           'łatwością': 1,
#           'okrąglaków': 1,
#           'głowy': 2,
#           'wyjeżdżaniem': 1,
#           'bezwładnego': 1,
#           'belek': 1,
#           'głodu': 1,
#           'brzegu': 1,
#           'siłami': 1,
#           'wdzięcznością': 1,
#           'czoła': 1,
#           'twarzy': 2,
#           'pokiereszowanymi': 1,
#           'wodą': 3,
#           'pochodzenia': 1,
#           'zadowoleniem': 3,
#           'irytacją': 1,
#           'głową': 1,
#           'kłody': 1,
#           'whisky': 1,
#           'nimi': 4,
#           'baru': 1,
#           'okrąglakami': 1,
#           'rosnącym': 3,
#           'mojego': 1,
#           'etykietki': 1,
#           'wątpliwością': 1,
#           'niezbyt': 1,
#           'portfela': 1,
#           'jakimś': 1,
#           'baterią': 1,
#           'uwagą': 1,
#           'szacunkiem': 2,
#           'pogodnym': 1,
#           'trudnością': 2,
#           'większą': 1,
#           'tą': 3,
#           'dumą': 1,
#           'rysami': 1,
#           'głębi': 1,
#           'winem': 1,
#           'butelką': 1,
#           'muszkatelem': 1,
#           'niego': 2,
#           'niedowierzaniem': 1,
#           'pieniędzmi': 1,
#           'zakupami': 1,
#           'chicago': 1,
#           'tamtejszych': 1,
#           'farmy': 1,
#           'procy': 2,
#           'młotkiem': 1,
#           'zamyśleniem': 1,
#           'nas': 2,
#           'osobna': 1,
#           'armatą': 1,
#           'matką': 1,
#           'innymi': 2,
#           'łóżka': 1,
#           'wysokim': 2,
#           'przewidywaniem': 1,
#           'nie': 1,
#           'otwartymi': 1,
#           'wyrazem': 1,
#           'kwiatów': 1,
#           'szafki': 1,
#           'lekami': 1,
#           'kremem': 1,
#           'takiej': 1,
#           'czasem': 1,
#           'raportem': 1,
#           'apteczki': 1,
#           'ich': 1,
#           'ciał': 1,
#           'przyzwyczajeniem': 1,
#           'odległości': 1,
#           'rzadka': 1,
#           'barów': 1,
#           'całych': 5,
#           'rozbitych': 1,
#           'każdą': 4,
#           'kul': 2,
#           'napisem': 2,
#           'dzikim': 1,
#           'ławkami': 1,
#           'masztem': 1,
#           'fontanny': 1,
#           'zielonych': 1,
#           'dobrze': 1,
#           'cienia': 3,
#           'waszych': 1,
#           'niczego': 3,
#           'ławki': 1,
#           'nikim': 1,
#           'przebywaniem': 1,
#           'rozpuszczonymi': 1,
#           'miękką': 1,
#           'ogromnych': 1,
#           'drabiny': 1,
#           'czynnych': 1,
#           'zimna': 2,
#           'drzewa': 1,
#           'otaczających': 1,
#           'panów': 1,
#           'zamkniętymi': 2,
#           'was': 1,
#           'iluzji': 1,
#           'tych': 1,
#           'mieszkańcami': 1,
#           'regułami': 1,
#           'wędrowcami': 2,
#           'moich': 1,
#           'trzaskiem': 1,
#           'dwojga': 1,
#           'chciwością': 1,
#           'węży': 1,
#           'centrum': 1,
#           'przerażeniem': 2,
#           'otchłani': 1,
#           'przejęciem': 1,
#           'zielonym': 1,
#           'grubymi': 1,
#           'papierosa': 1,
#           'kawą': 1,
#           'pozostałymi': 1,
#           'nachmurzoną': 1,
#           'kręgu': 2,
#           'rezygnacją': 1,
#           'wędrowniczek': 1,
#           'ożywionej': 1,
#           'zaciskającym': 1,
#           'połyskującymi': 1,
#           'ciemnego': 1,
#           'zajadłą': 1,
#           'pola': 1,
#           'drzwiami': 1,
#           'ramienia': 1,
#           'lewej': 1,
#           'pękniętego': 1,
#           'okazji': 1,
#           'furgonetki': 1,
#           'wisiał': 1,
#           'każda': 1,
#           'bólu': 1,
#           'namaszczeniem': 1,
#           'przyjemnością': 1,
#           'ukrycia': 1,
#           'dużą': 1,
#           'wysiłkiem': 1,
#           'trwogą': 1,
#           'lewarem': 1,
#           'tobą': 1,
#           'christopherem': 1,
#           'oczodołów': 1,
#           'rozkraczonymi': 1,
#           'flagą': 1,
#           'cegły': 1,
#           'klubu': 1,
#           'kuflem': 1,
#           'mieszanymi': 1,
#           'neonami': 1,
#           'przyszłością': 1,
#           'każdym': 1,
#           'wieloma': 1,
#           'barierą': 1}),
#  'gibson, z, zachwytem': Counter({'i': 1, '#sum': 1}),
#  'zachwytem': Counter({'i': 1, '#sum': 1}),
#  'z, zachwytem, i': Counter({'miłością': 1, '#sum': 1}),
#  'i': Counter({'miłością': 1,
#           '#sum': 938,
#           'walter': 2,
#           'odpoczywali': 2,
#           'postawiła': 1,
#           'toporne': 1,
#           'szybko': 4,
#           'odpowiednio': 1,
#           'przesunął': 1,
#           'szeroko': 1,
#           'nogi': 4,
#           'dziwnie': 1,
#           'obserwować': 1,
#           'uformowawszy': 1,
#           'cofnął': 3,
#           'żałośnie': 1,
#           'pani': 1,
#           'czarnymi': 2,
#           'spoglądając': 1,
#           'rzekł': 1,
#           'zaczerwieniona': 1,
#           'usiadł': 5,
#           'pocierając': 1,
#           'po': 7,
#           'zaczął': 8,
#           'drzew': 1,
#           'topole': 1,
#           'oczywiście': 1,
#           'zbliżali': 1,
#           'zaczęła': 1,
#           'usadowiwszy': 1,
#           'spojrzał': 7,
#           'tym': 2,
#           'to': 6,
#           'ten': 3,
#           'nerwowo': 2,
#           'pończochy': 1,
#           'brudna': 1,
#           'peg': 1,
#           'byłoby': 1,
#           'gór': 2,
#           'przełęczy': 1,
#           'zupełnie': 1,
#           'potworne': 1,
#           'tę': 1,
#           'jesteśmy': 1,
#           'walących': 1,
#           'porośnięta': 1,
#           'pełna': 1,
#           'wyjął': 8,
#           'wiem': 1,
#           'wlepił': 1,
#           'wirginii': 1,
#           'skupiska': 1,
#           'spędził': 1,
#           'przejeżdżając': 1,
#           'sklepy': 2,
#           'zaparkowane': 1,
#           'nagle': 5,
#           'tanie': 2,
#           'warzywa': 1,
#           'minął': 2,
#           'staranniej': 1,
#           'wyjechał': 2,
#           'stacjami': 1,
#           'te': 2,
#           'przestraszony': 1,
#           'wychowałem': 2,
#           'zeskoczył': 1,
#           'środki': 1,
#           'otworzywszy': 2,
#           'szelki': 1,
#           'ołówki': 1,
#           'ogólny': 1,
#           'podszedł': 6,
#           'wskazał': 1,
#           'z': 13,
#           'ruszył': 9,
#           'warzyw': 1,
#           'założyła': 1,
#           'przeczytał': 1,
#           'czym': 1,
#           'krzyknęła': 1,
#           'papy': 1,
#           'równie': 1,
#           'zapalił': 2,
#           'przypalał': 1,
#           'sapał': 1,
#           'położył': 1,
#           'zgonów': 1,
#           'przebiegł': 2,
#           'poruszał': 2,
#           'tu': 1,
#           'odniósł': 1,
#           'wyjechała': 1,
#           'wolno': 3,
#           'wszystko': 2,
#           'sarah': 2,
#           'omal': 2,
#           'niemal': 2,
#           'pójść': 1,
#           'włączył': 1,
#           'podniósł': 6,
#           'topornego': 1,
#           'jego': 6,
#           'poproś': 2,
#           'ledwo': 1,
#           'zbladł': 1,
#           'zamarł': 2,
#           'obejrzał': 2,
#           'złapał': 2,
#           'w': 10,
#           'zaczęli': 1,
#           'minąwszy': 1,
#           'popędził': 1,
#           'złapać': 1,
#           'zamienił': 1,
#           'noaks': 1,
#           'gładka': 1,
#           'otworzyły': 1,
#           'stosunkowo': 1,
#           'białe': 4,
#           'poplamiona': 1,
#           'przekręcony': 1,
#           'wychudła': 1,
#           'kaprawe': 1,
#           'zapytał': 2,
#           'trochę': 1,
#           'zapalniczkę': 1,
#           'lekkim': 1,
#           'poszedł': 3,
#           'ile': 1,
#           'skierowała': 1,
#           'obrazka': 1,
#           'obiad': 1,
#           'wręczył': 1,
#           'głowa': 1,
#           'odchodzili': 1,
#           'zaskoczonego': 1,
#           'wyjeżdżających': 1,
#           'nie': 9,
#           'spękana': 1,
#           'walące': 1,
#           'obaj': 1,
#           'podał': 2,
#           'oddał': 1,
#           'siadam': 1,
#           'on': 3,
#           'dodał': 4,
#           'jak': 4,
#           'co': 6,
#           'dokładnie': 1,
#           'wrogość': 1,
#           'otworzył': 3,
#           'pogardą': 1,
#           'zaraz': 3,
#           'usłyszał': 1,
#           'krzyknął': 2,
#           'skierował': 3,
#           'gnojem': 1,
#           'czekał': 3,
#           'przebiegając': 1,
#           'zdjął': 2,
#           'postawił': 2,
#           'sięgnął': 1,
#           'pogłaskał': 2,
#           'rękaw': 1,
#           'zamknął': 2,
#           'węszącymi': 1,
#           'zdrowe': 1,
#           'powiesił': 1,
#           'zajął': 1,
#           'obliczył': 1,
#           'wyszedł': 2,
#           'rzucił': 2,
#           'machając': 1,
#           'niepewnie': 1,
#           'cały': 2,
#           'ramię': 1,
#           'wrócił': 1,
#           'obie': 1,
#           'będzie': 1,
#           'zmętniała': 1,
#           'wytarł': 1,
#           'dobrze': 1,
#           'prowadzę': 1,
#           'piekła': 1,
#           'był': 1,
#           'znaczenia': 1,
#           'mieszkam': 1,
#           'wstał': 1,
#           'sofie': 1,
#           'spiec': 1,
#           'kilku': 1,
#           'sprawia': 1,
#           'doktor': 1,
#           'udawać': 1,
#           'panią': 1,
#           'obcego': 1,
#           'żałuję': 1,
#           'kobieta': 1,
#           'jasną': 1,
#           'innych': 1,
#           'spoczywających': 1,
#           'ścianę': 1,
#           'zniknęli': 1,
#           'przez': 2,
#           'słoneczny': 1,
#           'drzewa': 2,
#           'krzesłach': 1,
#           'odczynnikami': 1,
#           'hałda': 1,
#           'ziemi': 1,
#           'usadowiła': 1,
#           'ledwie': 2,
#           'używa': 1,
#           'rozdeptała': 1,
#           'zranić': 1,
#           'dodała': 1,
#           'strzepnęła': 1,
#           'wylądowała': 1,
#           'niepewny': 1,
#           'źle': 1,
#           'schody': 1,
#           'próśb': 1,
#           'niepokojem': 1,
#           'bezwiednie': 1,
#           'paproci': 1,
#           'wsadził': 2,
#           'bardzo': 1,
#           'sofy': 1,
#           'odpoczywających': 1,
#           'zagląda': 1,
#           'samochód': 1,
#           'pojedzie': 1,
#           'otaczające': 1,
#           'cicho': 1,
#           'widziało': 1,
#           'domy': 2,
#           'zrobił': 1,
#           'srebrnej': 1,
#           'puścił': 1,
#           'strząsnął': 1,
#           'błękitnym': 1,
#           'ostry': 1,
#           'masywne': 1,
#           'mgłę': 1,
#           'światłem': 1,
#           'barton': 4,
#           'winorośli': 3,
#           'mgły': 1,
#           'swojego': 1,
#           'pod': 2,
#           'sosny': 1,
#           'szczelin': 1,
#           'trawa': 1,
#           'gwałtownie': 1,
#           'dwa': 1,
#           'nic': 1,
#           'zapomnieć': 1,
#           'dalej': 1,
#           'makabrycznego': 1,
#           'bez': 1,
#           'ciężarówka': 1,
#           'otoczona': 1,
#           'były': 2,
#           'stoczyć': 1,
#           'przeskoczywszy': 1,
#           'nerwowy': 1,
#           'odpocząć': 2,
#           'leżała': 1,
#           'przeskoczył': 1,
#           'przywarł': 1,
#           'popękany': 1,
#           'upadł': 1,
#           'wyjść': 1,
#           'wciągnąć': 1,
#           'pomylił': 1,
#           'przechylały': 1,
#           'spadł': 1,
#           'rozciągnął': 1,
#           'trzęsąc': 1,
#           'szczerzył': 1,
#           'teraz': 2,
#           'umrzeć': 1,
#           'pozwolił': 1,
#           'późno': 1,
#           'wskoczył': 1,
#           'zwolnił': 1,
#           'poruszali': 2,
#           'wchodził': 1,
#           'zamówił': 1,
#           'peterze': 1,
#           'mieli': 1,
#           'skoncentrował': 2,
#           'przygarbiony': 1,
#           'szczątki': 1,
#           'założył': 1,
#           'powiedział': 1,
#           'pójdę': 1,
#           'christopher': 5,
#           'pochylił': 2,
#           'tak': 2,
#           'pchnął': 1,
#           'czasu': 1,
#           'posłucha': 1,
#           'centralna': 1,
#           'tamte': 1,
#           'mną': 1,
#           'ciemno': 2,
#           'stwierdziłem': 1,
#           'się': 1,
#           'ona': 1,
#           'pogmerał': 1,
#           'namacał': 1,
#           'klnąc': 1,
#           'weszli': 1,
#           'zlew': 1,
#           'śmieciami': 1,
#           'czasopisma': 1,
#           'stare': 1,
#           'jakieś': 2,
#           'naprawa': 2,
#           'poszedłem': 1,
#           'znalazłem': 1,
#           'prasowalnice': 1,
#           'łamię': 1,
#           'fach': 1,
#           'izolacji': 1,
#           'przysiadł': 1,
#           'drzwi': 1,
#           'zamachał': 2,
#           'zbliżył': 1,
#           'odszukał': 1,
#           'wkręcił': 2,
#           'przyjrzał': 1,
#           'zamyślił': 1,
#           'wino': 1,
#           'odstawił': 1,
#           'wpuścili': 1,
#           'wyrzucił': 1,
#           'stary': 1,
#           'pocąc': 1,
#           'niech': 2,
#           'uniósł': 1,
#           'przełączników': 1,
#           'wetknął': 1,
#           'stożek': 1,
#           'za': 1,
#           'skrzyżowawszy': 1,
#           'zastygł': 2,
#           'czknął': 1,
#           'ponownie': 2,
#           'przeciągle': 1,
#           'przenikliwe': 1,
#           'wyrazistego': 1,
#           'sprawiał': 1,
#           'westchnął': 1,
#           'poczuł': 2,
#           'spowili': 1,
#           'może': 2,
#           'pachniał': 1,
#           'mechanizm': 1,
#           'każdy': 1,
#           'ludzi': 1,
#           'na': 5,
#           'uroczyście': 1,
#           'dana': 1,
#           'wytrząsną': 1,
#           'spłynęło': 1,
#           'przegub': 1,
#           'do': 1,
#           'postrzępionego': 2,
#           'krzyczał': 1,
#           'pokrzykiwali': 1,
#           'łyżki': 1,
#           'ujął': 1,
#           'walnął': 1,
#           'dotknął': 2,
#           'gwoździami': 1,
#           'odłożył': 1,
#           'wygląd': 1,
#           'towarzyszący': 1,
#           'uderzenie': 1,
#           'trzymaną': 1,
#           'wycierał': 1,
#           'osłabiony': 1,
#           'odtworzyć': 1,
#           'kształtów': 1,
#           'warsztat': 1,
#           'ojcem': 1,
#           'indian': 1,
#           'przemykające': 1,
#           'ówdzie': 3,
#           'myszy': 1,
#           'armata': 1,
#           'jonesa': 1,
#           'rutledge': 1,
#           'zatrzymał': 1,
#           'wytężył': 1,
#           'wstała': 1,
#           'tęga': 1,
#           'pokaźne': 1,
#           'zatrzymała': 2,
#           'podbiegła': 1,
#           'dotknęła': 1,
#           'ciepłe': 1,
#           'naniesione': 1,
#           'my': 1,
#           'o': 2,
#           'skupiła': 1,
#           'zniknęła': 2,
#           'odbyło': 1,
#           'gnijącego': 1,
#           'zamarła': 1,
#           'zwinne': 1,
#           'patrzeć': 1,
#           'wielkość': 1,
#           'muchach': 1,
#           'takie': 1,
#           'opierała': 1,
#           'skręcił': 1,
#           'ruszyła': 2,
#           'starannie': 2,
#           'zaniosła': 1,
#           'giętka': 1,
#           'spięła': 1,
#           'pudełko': 1,
#           'dłonie': 1,
#           'zjadła': 1,
#           'łzy': 1,
#           'złapała': 1,
#           'falowało': 1,
#           'jej': 1,
#           'przytłaczający': 1,
#           'tego': 1,
#           'nóg': 2,
#           'upadła': 3,
#           'upadło': 1,
#           'nieprzyjemna': 1,
#           'podeszła': 3,
#           'uwolniła': 1,
#           'gigantyczna': 1,
#           'bluzkę': 1,
#           'buty': 1,
#           'starła': 1,
#           'rąk': 1,
#           'włożyła': 1,
#           'opadała': 2,
#           'budynków': 1,
#           'pobiegła': 1,
#           'krzyczeli': 1,
#           'gestykulowali': 1,
#           'krzycząc': 3,
#           'werandy': 1,
#           'potem': 1,
#           'wówczas': 2,
#           'coś': 1,
#           'skoncentruje': 1,
#           'mosiężna': 1,
#           'rozpłynęły': 1,
#           'betonowa': 1,
#           'brodziły': 1,
#           'musieli': 1,
#           'mglisty': 1,
#           'niknął': 1,
#           'ścieżki': 1,
#           'obok': 1,
#           'ciężko': 1,
#           'opuścili': 1,
#           'przyjął': 1,
#           'usiadła': 1,
#           'niedowierzaniem': 1,
#           'również': 1,
#           'owo': 1,
#           'powlókł': 1,
#           'postanowię': 1,
#           'pchnęła': 1,
#           'kiedy': 1,
#           'poszli': 1,
#           'zastanawiając': 1,
#           'uległo': 1,
#           'ciemności': 1,
#           'obiegłszy': 1,
#           'ocenić': 1,
#           'dzbanów': 1,
#           'wyjęła': 1,
#           'skoncentrowała': 1,
#           'zwinęła': 1,
#           'zeszła': 1,
#           'przeniosła': 1,
#           'cała': 1,
#           'rozmasowała': 1,
#           'pić': 1,
#           'syrop': 1,
#           'szafę': 1,
#           'otuliła': 1,
#           'strącała': 1,
#           'krzyczała': 1,
#           'wspinały': 1,
#           'walczyła': 1,
#           'oczy': 1,
#           'oślepiały': 1,
#           'opadła': 1,
#           'ciało': 1,
#           'zatopiły': 1,
#           'zachowywać': 1,
#           'kapeluszu': 1,
#           'czekali': 1,
#           'wyglądał': 1,
#           'szeleściły': 1,
#           'opuścił': 1,
#           'stos': 1,
#           'poszła': 1,
#           'kapelusz': 1,
#           'spacerować': 1,
#           'mają': 1,
#           'prawdziwe': 1,
#           'ja': 1,
#           'wędrowcy': 1,
#           'córkę': 1,
#           'mroku': 1,
#           'tam': 1,
#           'zimnego': 1,
#           'odwieczna': 1,
#           'wytryskiwał': 1,
#           'ogrzewały': 1,
#           'ruchem': 1,
#           'śmierć': 3,
#           'trwanie': 1,
#           'zło': 1,
#           'prawdę': 1,
#           'wchłonie': 1,
#           'potrwa': 1,
#           'iluzji': 1,
#           'uśmiercono': 1,
#           'i': 2,
#           'warczały': 1,
#           'oddalił': 1,
#           'rękach': 1,
#           'szczurów': 1,
#           'przyśpieszył': 1,
#           'głównej': 1,
#           'głową': 3,
#           'bezruchem': 1,
#           'niecierpliwością': 1,
#           'jarzyło': 1,
#           'całkowicie': 1,
#           'pochłaniał': 1,
#           'starą': 1,
#           'jakimś': 1,
#           'zgniótł': 1,
#           'wargi': 1,
#           'docisnął': 1,
#           'usta': 1,
#           'zmarły': 1,
#           'włożył': 1,
#           'zadowolenie': 1,
#           'kucnął': 1,
#           'pomacał': 1,
#           'oszołomiony': 1,
#           'wykazy': 1,
#           'piżamach': 1,
#           'czujni': 1,
#           'dlatego': 1,
#           'wiedziałem': 1,
#           'otwierał': 1,
#           'zniekształcone': 1,
#           'raportów': 1,
#           'rejestrów': 1,
#           'sprzęt': 1,
#           'piły': 1,
#           'jest': 1,
#           'prawdopodobnie': 1,
#           'spojrzała': 1,
#           'hildę': 1,
#           'posłuchajcie': 1,
#           'przysłany': 1,
#           'czekać': 1,
#           'odchyliła': 1,
#           'kobiety': 1,
#           'oczyścili': 1,
#           'krzaki': 1,
#           'leżącego': 1,
#           'szkice': 1,
#           'otumanione': 1,
#           'tropił': 1,
#           'nigdy': 1,
#           'wszelkie': 1,
#           'zespół': 1,
#           'patrzył': 1,
#           'odpowiednim': 1,
#           'maleńkich': 1,
#           'przywołuje': 1,
#           'przegraliśmy': 1,
#           'wzgórze': 1,
#           'wężami': 1,
#           'falował': 1,
#           'spiesznie': 1,
#           'zgromadzili': 1,
#           'przestraszeni': 1,
#           'odrzucił': 1,
#           'złowrogo': 1,
#           'zrobiła': 1,
#           'reszta': 1,
#           'rozgniótł': 2,
#           'zachwiała': 1,
#           'depcząc': 1,
#           'dziesięciocentymetrowych': 1,
#           'golemy': 2,
#           'niezdarnie': 1,
#           'golemach': 1,
#           'drgało': 1,
#           'szczury': 1,
#           'wymachiwał': 1,
#           'mułem': 1,
#           'węże': 2,
#           'wchłaniał': 1,
#           'wydychał': 1,
#           'próżni': 1,
#           'wbiegł': 1,
#           'skręcając': 1,
#           'wyżej': 1,
#           'kipiącej': 1,
#           'zorientować': 1,
#           'szykował': 1,
#           'padł': 2,
#           'wskakiwały': 1,
#           'garnitur': 1,
#           'pomknął': 1,
#           'goleniami': 1,
#           'wrzucały': 1,
#           'wyrżnął': 1,
#           'zgrzytając': 1,
#           'ześlizgnął': 1,
#           'zaryła': 1,
#           'benzyna': 1,
#           'pająki': 1,
#           'podrapaną': 1,
#           'wyobraził': 1,
#           'chwiejąc': 1,
#           'zakołysał': 1,
#           'zapadała': 1,
#           'odrażające': 1,
#           'długie': 1,
#           'rozgnieciony': 1,
#           'porzucony': 1,
#           'przemieniła': 1,
#           'podryfowały': 1,
#           'ta': 1,
#           'kipiały': 1,
#           'niewyczuwalny': 1,
#           'niezliczone': 1,
#           'obracał': 1,
#           'kołysała': 1,
#           'świecących': 1,
#           'spróbował': 1,
#           'błagał': 1,
#           'znalazł': 1,
#           'odbiła': 1,
#           'ciężar': 1,
#           'spada': 1,
#           'spadało': 1,
#           'zawył': 1,
#           'drogę': 1,
#           'golemów': 1,
#           'zapachy': 1,
#           'porzucona': 1,
#           'przechyliła': 1,
#           'zamieniła': 1,
#           'węży': 1,
#           'wstrzymał': 1,
#           'poza': 1,
#           'wyciągnął': 1,
#           'wskoczyła': 1,
#           'spędzić': 1,
#           'modele': 1,
#           'planarni': 1,
#           'ormuzd': 1,
#           'zamilkł': 1,
#           'niewielki': 1,
#           'więcej': 1,
#           'powiódł': 1,
#           'duże': 1,
#           'pulsowała': 1,
#           'winorośl': 1,
#           'przymknął': 1,
#           'wypoczęty': 1,
#           'masztu': 1,
#           'ulic': 1,
#           'betonu': 1,
#           'wychodzili': 1,
#           'patrzyło': 1,
#           'wesołym': 1,
#           'punktu': 1,
#           'nawet': 1,
#           'pokryła': 1,
#           'spodnie': 1,
#           'skórzany': 1,
#           'pojawił': 1,
#           'przystąpić': 1,
#           'uśmiechnął': 1,
#           'uścisnęli': 1,
#           'urządzony': 1,
#           'starej': 1,
#           'doktorem': 1,
#           'zarośnięta': 1,
#           'rozsypanych': 1,
#           'wiedział': 1,
#           'oczu': 1,
#           'lasach': 1,
#           'górach': 1,
#           'wokół': 1}),
#  'zachwytem, i, miłością': Counter({'1': 1, '#sum': 1}),
#  'miłością': Counter({'1': 1, '#sum': 1}),
#  'i, miłością, 1': Counter({'peter': 1, '#sum': 1}),
#  '1': Counter({'peter': 1, '#sum': 1}),
#  'miłością, 1, peter': Counter({'trilling': 1, '#sum': 1}),
#  'peter': Counter({'trilling': 6,
#           '#sum': 90,
#           'obserwował': 1,
#           'odsunął': 2,
#           'zsunął': 1,
#           'jego': 1,
#           'nic': 1,
#           'zaśmiał': 2,
#           'zrolował': 1,
#           'chwytając': 1,
#           'dogonił': 1,
#           'zdrapując': 1,
#           'widział': 1,
#           'poruszył': 1,
#           'obrócił': 2,
#           'chce': 1,
#           'mieszkasz': 1,
#           'zaczął': 1,
#           'odwrócił': 1,
#           'powiedział': 1,
#           'wzruszył': 1,
#           'był': 4,
#           'wyraźnie': 1,
#           'przerwał': 1,
#           'wziął': 1,
#           'musiał': 2,
#           'wstał': 1,
#           'do': 1,
#           'krzyknął': 1,
#           'toczył': 1,
#           'córka': 1,
#           'ma': 1,
#           'będzie': 1,
#           'bawił': 1,
#           'zamrugał': 1,
#           'i': 2,
#           'stal': 1,
#           'możemy': 1,
#           'dotknął': 1,
#           'przykucnął': 1,
#           'nie': 2,
#           'nagle': 1,
#           'udawał': 1,
#           'to': 1,
#           'wskazując': 1,
#           'wsadził': 1,
#           'może': 2,
#           'na': 1,
#           'zbliżając': 1,
#           'coś': 1,
#           'uśmiechnął': 1,
#           'potrzymałem': 1,
#           'podbiegając': 1,
#           'przechodzi': 1,
#           'posługiwał': 1,
#           'w': 1,
#           'czekała': 1,
#           'wolał': 1,
#           'wciąż': 1,
#           'bez': 1,
#           'odparta': 1,
#           'tam': 1,
#           'mógł': 1,
#           'zamontował': 1,
#           'wypuścił': 1,
#           'również': 1,
#           'ją': 1,
#           'ruszył': 1,
#           'nigdy': 1,
#           'wyprostował': 1,
#           'zrozumiał': 1,
#           'hilda': 1,
#           'pojawił': 1,
#           'miał': 1,
#           'o': 1,
#           'pożyczył': 1}),
#  '1, peter, trilling': Counter({'przyglądał': 1, '#sum': 1}),
#  'trilling': Counter({'przyglądał': 1,
#           '#sum': 25,
#           'zeszli': 1,
#           'i': 2,
#           'wycierając': 1,
#           'jeśli': 1,
#           'weszła': 1,
#           'kucnął': 1,
#           'facet': 1,
#           'spojrzała': 2,
#           'wyraźnie': 1,
#           'pośpieszyła': 1,
#           'wchodząc': 1,
#           'odetchnęła': 1,
#           'przeszedł': 1,
#           'nie': 1,
#           'siedząca': 1,
#           'mi': 1,
#           'jego': 1,
#           'pozostali': 1,
#           'zapytał': 1,
#           'podparł': 1,
#           'trącił': 1,
#           'a': 1}),
#  'peter, trilling, przyglądał': Counter({'się': 1, '#sum': 1}),
#  'przyglądał': Counter({'się': 3, '#sum': 4, 'mu': 1}),
#  'trilling, przyglądał, się': Counter({'spokojnie': 1, '#sum': 1}),
#  'się': Counter({'spokojnie': 1,
#           '#sum': 1113,
#           'na': 53,
#           'zawzięcie': 1,
#           'i': 41,
#           'opierając': 1,
#           'do': 47,
#           'czego': 2,
#           'pani': 3,
#           'ze': 8,
#           'pobawię': 1,
#           'z': 38,
#           'po': 26,
#           'o': 6,
#           'przed': 8,
#           'ujrzeć': 1,
#           'a': 4,
#           'podziwem': 1,
#           'kiedykolwiek': 1,
#           'przez': 7,
#           'ogrodzeń': 1,
#           'wręcz': 1,
#           'niewielka': 1,
#           'strumień': 1,
#           'urodził': 2,
#           'zmieniło': 3,
#           'ludzie': 1,
#           'stało': 14,
#           'całkowicie': 1,
#           'w': 62,
#           'urodziłem': 1,
#           'rękoma': 5,
#           'drewniany': 1,
#           'żółtą': 1,
#           'podział': 1,
#           'tam': 8,
#           'wolno': 4,
#           'pan': 12,
#           'panu': 5,
#           'mały': 1,
#           'zakłopotanie': 1,
#           'szybko': 8,
#           'hotele': 1,
#           'zgubiłem': 1,
#           'oddalił': 1,
#           'głośno': 1,
#           'znowu': 4,
#           'nie': 21,
#           'millgate': 2,
#           'że': 31,
#           'pośpieszyć': 1,
#           'palcami': 1,
#           'błąd': 1,
#           'robi': 1,
#           'czas': 1,
#           'stanąwszy': 1,
#           'peg': 1,
#           'czujesz': 1,
#           'coś': 4,
#           'razem': 4,
#           'swoim': 1,
#           'najpierw': 1,
#           'od': 9,
#           'przenikliwym': 1,
#           'sprężyście': 1,
#           'pierwszy': 1,
#           'znaleźć': 2,
#           'bać': 1,
#           'drzwi': 1,
#           'nieznacznie': 1,
#           'dłonią': 1,
#           'temu': 2,
#           'plecami': 2,
#           'za': 8,
#           'ruszać': 1,
#           'ożywiła': 1,
#           'wyraz': 3,
#           'tu': 13,
#           'bez': 1,
#           'targować': 1,
#           'jeść': 1,
#           'nieszczególnie': 1,
#           'dowiedzieć': 3,
#           'ironicznie': 1,
#           'barton': 12,
#           'wahał': 2,
#           'usatysfakcjonowany': 1,
#           'jego': 3,
#           'nieswojo': 3,
#           'wzgórza': 1,
#           'płoty': 1,
#           'byłeś': 1,
#           'ogarnięty': 1,
#           'bałem': 1,
#           'czy': 1,
#           'nazywają': 1,
#           'złapać': 2,
#           'uczepić': 1,
#           'jeszcze': 6,
#           'dowiem': 1,
#           'obchodzić': 1,
#           'nauczył': 1,
#           'zbladł': 1,
#           'wycofać': 2,
#           'kroków': 1,
#           'pod': 9,
#           'przytłumiony': 1,
#           'wygodnie': 3,
#           'aż': 2,
#           'nieznajomy': 1,
#           'okazać': 1,
#           'dwie': 1,
#           'wyciągnął': 1,
#           'ponad': 1,
#           'leniwie': 1,
#           'światło': 3,
#           'obserwując': 1,
#           'przeszkloną': 1,
#           'niewiele': 1,
#           'udało': 5,
#           'trząsł': 1,
#           'ich': 2,
#           'cieszyła': 1,
#           'bezpieczny': 1,
#           'trzymają': 1,
#           'prawie': 1,
#           'twardą': 1,
#           'meade': 1,
#           'gotować': 1,
#           'nad': 4,
#           'ożywił': 2,
#           'pomagać': 1,
#           'jak': 4,
#           'och': 1,
#           'mieli': 1,
#           'bliżej': 1,
#           'nadając': 1,
#           'jakoś': 2,
#           'rozumieć': 1,
#           'nagle': 6,
#           'siedziała': 1,
#           'wieczornym': 1,
#           'doktor': 3,
#           'książkami': 1,
#           'panna': 2,
#           'mylę': 1,
#           'dzieje': 2,
#           'niech': 2,
#           'pojawiły': 1,
#           'potwierdziła': 1,
#           'spodoba': 1,
#           'ów': 1,
#           'wyraźnie': 1,
#           'dolina': 1,
#           'trochę': 3,
#           'tak': 2,
#           'zbytnio': 1,
#           'moją': 1,
#           'oczywiście': 1,
#           'ostrożnie': 4,
#           'pszczoła': 1,
#           'czegoś': 2,
#           'pewnie': 1,
#           'tylko': 1,
#           'uzyskać': 1,
#           'odległy': 1,
#           'histeryczny': 1,
#           'nigdzie': 1,
#           'już': 6,
#           'powiesił': 1,
#           'obawiał': 1,
#           'zza': 1,
#           'jakąś': 1,
#           'kępką': 1,
#           'spojrzał': 1,
#           'pokazać': 1,
#           'poszedł': 1,
#           'pająków': 2,
#           'pszczół': 1,
#           'całą': 1,
#           'je': 1,
#           'tutaj': 4,
#           'ukryć': 1,
#           'peter': 1,
#           'obok': 1,
#           'poza': 1,
#           'nazywa': 1,
#           'widoku': 1,
#           'go': 1,
#           'wokół': 4,
#           'czymś': 1,
#           'częścią': 1,
#           'gęsto': 1,
#           'rys': 1,
#           'gdy': 1,
#           'wyjechać': 1,
#           'spodziewać': 1,
#           'była': 1,
#           'spiętrzyły': 1,
#           'zdarzało': 1,
#           'gorąco': 1,
#           'ją': 2,
#           'pokonać': 1,
#           'przezeń': 1,
#           'nieco': 2,
#           'szybki': 1,
#           'przepaść': 1,
#           'tędy': 1,
#           'to': 6,
#           'mocno': 1,
#           'podciągnąć': 1,
#           'sapiąc': 1,
#           'przedostać': 1,
#           'ciężarówki': 1,
#           'ani': 1,
#           'dookoła': 1,
#           'nerwowy': 1,
#           'wydostać': 1,
#           'leżał': 1,
#           'wieczór': 1,
#           'wyprowadzić': 1,
#           'chłodno': 2,
#           'uniosła': 1,
#           'szeroko': 1,
#           'pewny': 1,
#           'udać': 1,
#           'kiedy': 5,
#           'potem': 1,
#           'kafejki': 1,
#           'speluną': 1,
#           'niezdarnie': 1,
#           'zaledwie': 1,
#           'stąd': 2,
#           'przepitymi': 1,
#           'szkocką': 1,
#           'wtedy': 3,
#           'christopher': 6,
#           'szczerząc': 2,
#           'odnaleźć': 1,
#           'przygnębiony': 1,
#           'zmienił': 1,
#           'przecież': 1,
#           'skoncentrować': 1,
#           'zebrać': 1,
#           'konfidencjonalnie': 1,
#           'teraz': 3,
#           'u': 1,
#           'ta': 1,
#           'ukryłem': 1,
#           'zupełnie': 1,
#           'pojawili': 1,
#           'znalazłem': 1,
#           'podejrzliwie': 1,
#           'moce': 1,
#           'jakieś': 1,
#           'strach': 1,
#           'ona': 3,
#           'myli': 1,
#           'jednak': 1,
#           'pooranej': 1,
#           'wypił': 1,
#           'zamknięte': 1,
#           'chytry': 1,
#           'tabliczka': 1,
#           'sennie': 1,
#           'buczenie': 1,
#           'skupić': 2,
#           'obserwować': 1,
#           'mglista': 1,
#           'skoncentrował': 1,
#           'butelka': 3,
#           'patrzył': 1,
#           'lepiej': 1,
#           'cień': 2,
#           'plamą': 1,
#           'nabierając': 1,
#           'nieprzezroczysty': 1,
#           'zmiana': 1,
#           'mój': 1,
#           'podrzędny': 1,
#           'kłębek': 1,
#           'obecnie': 1,
#           'załzawiły': 1,
#           'stary': 1,
#           'trzymałem': 1,
#           'zebrał': 1,
#           'łyżka': 1,
#           'zimno': 1,
#           'zegar': 1,
#           'widoczna': 1,
#           'dojść': 1,
#           'pojawić': 1,
#           'ukazała': 1,
#           'wyraźniejszy': 1,
#           'rzeczywiście': 1,
#           'pojawiać': 2,
#           'stała': 1,
#           'czarna': 1,
#           'ręką': 1,
#           'ociężale': 1,
#           'tego': 3,
#           'gwałtownie': 1,
#           'nam': 3,
#           'ciemną': 1,
#           'zrobić': 1,
#           'chwilę': 2,
#           'ruder': 1,
#           'ptaki': 1,
#           'piramida': 1,
#           'przy': 4,
#           'ja': 1,
#           'skoncentruje': 1,
#           'uda': 2,
#           'sklepy': 2,
#           'wędrowiec': 1,
#           'cały': 1,
#           'dziwić': 1,
#           'ustalić': 1,
#           'dokładnie': 2,
#           'wędrowniczki': 1,
#           'jakiś': 1,
#           'mary': 3,
#           'rozejrzała': 1,
#           'nerwowo': 1,
#           'niecierpliwiła': 1,
#           'peterem': 1,
#           'wędrowniczka': 1,
#           'ale': 1,
#           'wątpliwość': 1,
#           'niecierpliwie': 1,
#           'niezwykle': 1,
#           'tedem': 1,
#           'nimi': 1,
#           'ledwie': 1,
#           'miała': 1,
#           'niecierpliwiły': 1,
#           'dłońmi': 1,
#           'pokaże': 2,
#           'przeliczył': 1,
#           'niepokoić': 1,
#           'wściekle': 1,
#           'badania': 1,
#           'nigdy': 1,
#           'nim': 1,
#           'zaraz': 1,
#           'pospieszyć': 1,
#           'skręca': 1,
#           'jej': 5,
#           'wyprostowała': 1,
#           'choć': 1,
#           'roześmiać': 1,
#           'niezgrabnie': 2,
#           'im': 2,
#           'opuszczonych': 1,
#           'źródłem': 1,
#           'coraz': 3,
#           'mniej': 1,
#           'zawahały': 1,
#           'wynurzać': 1,
#           'armacie': 1,
#           'zarysy': 1,
#           'armatą': 1,
#           'mglisty': 1,
#           'sklepów': 1,
#           'poklepali': 1,
#           'czując': 1,
#           'ujawnić': 1,
#           'powiedziała': 1,
#           'panom': 2,
#           'kompletnie': 1,
#           'badawczo': 1,
#           'panem': 1,
#           'śpieszyć': 1,
#           'dlaczego': 1,
#           'delikatnie': 1,
#           'kilka': 1,
#           'uważnie': 1,
#           'przedrzeć': 2,
#           'maksymalnie': 1,
#           'ciasno': 1,
#           'wokoło': 6,
#           'węże': 1,
#           'czarny': 1,
#           'szczelnie': 1,
#           'rozkazał': 1,
#           'cicho': 1,
#           'groźna': 1,
#           'jako': 1,
#           'stać': 1,
#           'ponieważ': 1,
#           'dokonywała': 1,
#           'pokonywać': 1,
#           'stawać': 1,
#           'ból': 1,
#           'podoba': 1,
#           'żałośnie': 1,
#           'nic': 1,
#           'pukanie': 1,
#           'kobiecy': 1,
#           'przepychały': 1,
#           'pogrążony': 1,
#           'aby': 3,
#           'wysoko': 1,
#           'nawzajem': 1,
#           'echem': 2,
#           'bezdźwięcznie': 1,
#           'krąg': 1,
#           'naprzód': 1,
#           'park': 1,
#           'zaczęło': 1,
#           'podejść': 1,
#           'kręgu': 1,
#           'pełna': 1,
#           'nieprzerwanie': 1,
#           'nowe': 1,
#           'pochodowi': 1,
#           'glinę': 1,
#           'ku': 1,
#           'dziwny': 1,
#           'oni': 1,
#           'mu': 1,
#           'siwowłosy': 1,
#           'inny': 2,
#           'śmiertelna': 1,
#           'niezauważalnie': 1,
#           'cichy': 1,
#           'dostać': 1,
#           'upewnić': 1,
#           'prawdy': 1,
#           'smutno': 1,
#           'wam': 1,
#           'najlepiej': 1,
#           'ciem': 1,
#           'przeniknąć': 1,
#           'twarzą': 1,
#           'zneutralizować': 1,
#           'kurczyć': 1,
#           'nikły': 1,
#           'jest': 1,
#           'niepowodzeniem': 1,
#           'odtworzyć': 1,
#           'zdała': 1,
#           'między': 2,
#           'gdybym': 1,
#           'boję': 1,
#           'źle': 1,
#           'niewesoło': 1,
#           'przede': 1,
#           'wąż': 1,
#           'pierścieniem': 1,
#           'były': 1,
#           'mankietów': 1,
#           'zbyt': 1,
#           'rozprzestrzeniała': 1,
#           'wędrowcy': 1,
#           'wraz': 1,
#           'było': 1,
#           'żywił': 1,
#           'zatrzymał': 1,
#           'wznosił': 1,
#           'poruszyło': 1,
#           'masę': 1,
#           'klęknąć': 1,
#           'podziała': 1,
#           'przegrał': 1,
#           'szamotać': 1,
#           'uwolnił': 1,
#           'rój': 1,
#           'dzień': 1,
#           'szczurami': 1,
#           'co': 2,
#           'uruchomić': 1,
#           'zataczając': 1,
#           'kobierzec': 1,
#           'chcąc': 1,
#           'kim': 1,
#           'kołnierza': 1,
#           'pobiegł': 1,
#           'rozchylił': 1,
#           'topiła': 1,
#           'przeraźliwy': 1,
#           'kul': 1,
#           'drobin': 1,
#           'zmieniać': 1,
#           'on': 1,
#           'rozrzedzać': 1,
#           'formować': 1,
#           'straszna': 1,
#           'ciałami': 1,
#           'długa': 1,
#           'rozszerzało': 1,
#           'swoimi': 1,
#           'cieniutki': 1,
#           'migotliwie': 1,
#           'bardziej': 1,
#           'świetnie': 1,
#           'dźwięcznym': 1,
#           'wymiana': 1,
#           'rozciąga': 1,
#           'koncentrować': 2,
#           'fioletowe': 1,
#           'rozmywać': 1,
#           'może': 1,
#           'krzewy': 1,
#           'dobrze': 1,
#           'zatrzymując': 1,
#           'dalej': 1,
#           'miało': 1,
#           'panie': 1,
#           'znajomy': 1,
#           'zatrzyma': 1,
#           'lada': 1,
#           'ręczna': 1,
#           'rozmazywać': 1,
#           'prezentujący': 1,
#           'zarys': 1,
#           'zmieniał': 1,
#           'tracąc': 1,
#           'trząść': 1,
#           'zniknęły': 1,
#           'sklep': 1,
#           'okazale': 1,
#           'doczekać': 1,
#           'zobaczymy': 1,
#           'wychował': 1,
#           'samochody': 1,
#           'miasto': 1,
#           'lekko': 1,
#           'gdzieś': 1,
#           'bogowie': 1,
#           'robiąc': 1,
#           'majestatycznie': 1}),
#  'przyglądał, się, spokojnie': Counter({'grupce': 1, '#sum': 1}),
#  'spokojnie': Counter({'grupce': 1,
#           '#sum': 9,
#           'peter': 3,
#           'jak': 1,
#           'christopher': 1,
#           'odpocząć': 1,
#           'hilda': 1,
#           'to': 1}),
#  'się, spokojnie, grupce': Counter({'dzieci': 1, '#sum': 1}),
#  'grupce': Counter({'dzieci': 1, '#sum': 1}),
#  'spokojnie, grupce, dzieci': Counter({'które': 1, '#sum': 1}),
#  'dzieci': Counter({'które': 1,
#           '#sum': 6,
#           'na': 1,
#           'grało': 1,
#           'umierały': 1,
#           'zmarło': 1,
#           'baraszkowały': 1}),
#  'grupce, dzieci, które': Counter({'bawiły': 1, '#sum': 1}),
#  'które': Counter({'bawiły': 1,
#           '#sum': 19,
#           'pamiętasz': 1,
#           'pamiętam': 1,
#           'znał': 1,
#           'tam': 1,
#           'grzechotały': 1,
#           'nie': 1,
#           'pełzły': 1,
#           'działają': 1,
#           'nadal': 1,
#           'odtworzyli': 1,
#           'pan': 1,
#           'szukały': 1,
#           'zostały': 1,
#           'napotkała': 1,
#           'miotały': 1,
#           'trawił': 1,
#           'syczały': 1,
#           'stale': 1}),
#  'dzieci, które, bawiły': Counter({'się': 1, '#sum': 1}),
#  'bawiły': Counter({'się': 1, '#sum': 1}),
#  'które, bawiły, się': Counter({'na': 1, '#sum': 1}),
#  'bawiły, się, na': Counter({'podwórzu': 1, '#sum': 1}),
#  'na': Counter({'podwórzu': 1,
#           '#sum': 608,
#           'mój': 1,
#           'ogonie': 1,
#           'to': 17,
#           'dolnym': 1,
#           'werandę': 5,
#           'piersi': 5,
#           'uboczu': 1,
#           'ziemi': 8,
#           'krowę': 1,
#           'bok': 10,
#           'zloty': 1,
#           'kolacji': 1,
#           'którym': 2,
#           'wzgórzach': 1,
#           'twarzy': 13,
#           'nim': 2,
#           'drodze': 2,
#           'jej': 7,
#           'tle': 8,
#           'widok': 2,
#           'dnie': 3,
#           'miejscu': 3,
#           'farmie': 2,
#           'ulicy': 12,
#           'hamulcu': 1,
#           'ten': 2,
#           'środku': 4,
#           'placu': 1,
#           'główną': 3,
#           'rozgrzaną': 1,
#           'ścianach': 1,
#           'niego': 11,
#           'myśli': 8,
#           'tabliczkę': 1,
#           'starym': 1,
#           'ladzie': 1,
#           'bartona': 14,
#           'świecie': 4,
#           'słońcu': 1,
#           'chodniku': 2,
#           'pewno': 10,
#           'drugą': 6,
#           'centralnej': 2,
#           'złej': 1,
#           'wprost': 1,
#           'kontuar': 2,
#           'zaplecze': 2,
#           'stole': 4,
#           'pożółkłym': 2,
#           'powrót': 1,
#           'tym': 7,
#           'skąpanej': 1,
#           'nich': 5,
#           'rogu': 2,
#           'ulice': 1,
#           'fotel': 1,
#           'szkarlatynę': 3,
#           'nowo': 1,
#           'swoim': 4,
#           'dwie': 1,
#           'przeciwny': 1,
#           'równe': 3,
#           'błyszczącym': 1,
#           'próżno': 1,
#           'nią': 12,
#           'steranego': 1,
#           'jedną': 2,
#           'zmęczoną': 1,
#           'syna': 1,
#           'zewnątrz': 14,
#           'odpoczynek': 2,
#           'piętro': 1,
#           'wzgórza': 1,
#           'ścianie': 1,
#           'korytarzu': 1,
#           'kilka': 3,
#           'chłopca': 1,
#           'zaniepokojonego': 2,
#           'niej': 6,
#           'pytania': 1,
#           'imię': 3,
#           'coś': 4,
#           'ilu': 1,
#           'dwudziestu': 1,
#           'długo': 1,
#           'razie': 7,
#           'mojej': 1,
#           'samym': 1,
#           'początku': 1,
#           'korytarz': 2,
#           'krótko': 1,
#           'całość': 1,
#           'jego': 14,
#           'pole': 1,
#           'strychu': 2,
#           'zardzewiałym': 1,
#           'stęchłym': 1,
#           'drugiej': 2,
#           'półkach': 1,
#           'pierwszy': 2,
#           'podwórze': 1,
#           'niewłaściwą': 1,
#           'oślep': 3,
#           'nogach': 4,
#           'otwartą': 1,
#           'szyi': 1,
#           'grubym': 1,
#           'potwierdzenie': 1,
#           'osłoniętą': 1,
#           'szczycie': 1,
#           'własny': 1,
#           'świat': 2,
#           'cmentarzu': 1,
#           'posterunku': 1,
#           'werandzie': 3,
#           'staromodnych': 1,
#           'żarówce': 1,
#           'oparciu': 1,
#           'drugim': 2,
#           'plecy': 2,
#           'zboczu': 1,
#           'dłoni': 2,
#           'ławkach': 2,
#           'trawie': 1,
#           'podłoże': 1,
#           'podkurczonych': 1,
#           'płatku': 1,
#           'zwiadzie': 1,
#           'szyję': 1,
#           'wtórnych': 1,
#           'pokarm': 1,
#           'kołnierzyku': 1,
#           'miłość': 1,
#           'wyjaśnianie': 1,
#           'właściwej': 1,
#           'próbę': 2,
#           'skalistej': 1,
#           'swojej': 3,
#           'zbocze': 1,
#           'góry': 1,
#           'żelaznych': 1,
#           'wszystkie': 2,
#           'gładkiej': 1,
#           'rów': 1,
#           'porozrzucane': 1,
#           'ciężarówkę': 1,
#           'dwa': 1,
#           'następną': 2,
#           'następny': 1,
#           'trzech': 1,
#           'wierzch': 1,
#           'kłodzie': 1,
#           'powierzchnię': 2,
#           'oświetloną': 1,
#           'zegarek': 2,
#           'tej': 2,
#           'zawsze': 3,
#           'dole': 2,
#           'pobyt': 1,
#           'ulicę': 2,
#           'ich': 4,
#           'końcu': 1,
#           'dokładkę': 1,
#           'sobie': 3,
#           'swoich': 2,
#           'stołku': 3,
#           'drinka': 1,
#           'barmana': 1,
#           'sto': 1,
#           'milion': 1,
#           'okrąglaku': 1,
#           'swoje': 2,
#           'narzędzia': 1,
#           'skraju': 3,
#           'podłogę': 2,
#           'krzesło': 2,
#           'ubranie': 1,
#           'skomplikowane': 1,
#           'podłodze': 4,
#           'głowę': 1,
#           'głowie': 1,
#           'butelce': 1,
#           'wpół': 1,
#           'niewiele': 2,
#           'plecach': 2,
#           'zmęczonego': 1,
#           'drewnianej': 1,
#           'odwracanie': 1,
#           'boga': 2,
#           'rękaw': 1,
#           'palce': 1,
#           'stałe': 1,
#           'kawałek': 1,
#           'dłużej': 1,
#           'krótką': 1,
#           'krawężniku': 1,
#           'kłębek': 1,
#           'oparcie': 1,
#           'róg': 1,
#           'ziemię': 4,
#           'wiotki': 1,
#           'kłębku': 1,
#           'chwilę': 2,
#           'łyżce': 2,
#           'pół': 1,
#           'darmo': 2,
#           'nogi': 1,
#           'wielką': 1,
#           'okoliczne': 1,
#           'pięćdziesiąt': 1,
#           'tamten': 1,
# ...
#  'z, trudem, wspinając': Counter({'się': 1, '#sum': 1}),
#  'wspinając': Counter({'się': 2, '#sum': 2}),
#  'trudem, wspinając, się': Counter({'po': 1, '#sum': 1}),
#  'wspinając, się, po': Counter({'stromych': 1, '#sum': 1}),
#  'się, po, stromych': Counter({'zboczach': 1, '#sum': 1}),
#  'stromych': Counter({'zboczach': 1, '#sum': 1}),
#  'po, stromych, zboczach': Counter({'wirginii': 1, '#sum': 1}),
#  'zboczach': Counter({'wirginii': 1, '#sum': 1}),
#  'stromych, zboczach, wirginii': Counter({'ted': 1, '#sum': 1}),
#  'wirginii': Counter({'ted': 1, '#sum': 3, 'chwilami': 1, 'cóż': 1}),
#  'zboczach, wirginii, ted': Counter({'wracajmy': 1, '#sum': 1}),
#  'ted': Counter({'wracajmy': 1,
#           '#sum': 22,
#           'barton': 11,
#           'czuję': 1,
#           'co': 2,
#           'podbiegła': 1,
#           'usłyszał': 1,
#           'mam': 1,
#           'powiedziała': 1,
#           'wypuścił': 1,
#           'hm': 1,
#           'ted': 1}),
#  'wirginii, ted, wracajmy': Counter({'jęknęła': 1, '#sum': 1}),
#  'wracajmy': Counter({'jęknęła': 1, '#sum': 1}),
#  'ted, wracajmy, jęknęła': Counter({'peggy': 1, '#sum': 1}),
#  'jęknęła': Counter({'peggy': 1, '#sum': 3, 'peg': 1, 'i': 1}),
#  'wracajmy, jęknęła, peggy': Counter({'barton': 1, '#sum': 1}),
#  'peggy': Counter({'barton': 1, '#sum': 1}),
#  'jęknęła, peggy, barton': Counter({'mam': 1, '#sum': 1}),
#  'barton': Counter({'mam': 2,
#           '#sum': 417,
#           'opuścił': 3,
#           'zmienił': 1,
#           'wychylił': 1,
#           'wciągnął': 2,
#           'z': 8,
#           'skierował': 1,
#           'zwolnił': 2,
#           'nie': 25,
#           'nadal': 1,
#           'zatrzymał': 3,
#           'mógł': 2,
#           'pociągnął': 1,
#           'przeszedł': 2,
#           'stary': 1,
#           'miał': 2,
#           'od': 1,
#           'syn': 1,
#           'zdezorientowany': 1,
#           'kupił': 1,
#           'kiedyś': 1,
#           'wycofał': 1,
#           'znalazł': 1,
#           'potknął': 1,
#           'musi': 2,
#           'wszedł': 2,
#           'chciałbym': 1,
#           'zazgrzytał': 1,
#           'usiadł': 6,
#           'trzęsącymi': 2,
#           '3050': 1,
#           'lat': 1,
#           'zamieszkałych': 1,
#           'wstał': 7,
#           'nic': 5,
#           'tylko': 1,
#           'jest': 6,
#           'przypuszczani': 1,
#           'ruszył': 3,
#           'są': 2,
#           'wsadził': 1,
#           'potrząsnął': 1,
#           'zapalił': 1,
#           'odwrócił': 1,
#           'poznał': 2,
#           'zesztywniał': 1,
#           'ted': 2,
#           'chłopiec': 2,
#           'przez': 2,
#           'zrozumiał': 1,
#           'zaczął': 3,
#           'ile': 1,
#           'zawahał': 1,
#           'wyczuł': 1,
#           'ostrożnie': 1,
#           'peter': 1,
#           'powiedział': 3,
#           'niepewnie': 1,
#           'dobry': 1,
#           'był': 4,
#           'jego': 3,
#           'poszedł': 1,
#           'co': 3,
#           'stał': 2,
#           'musiał': 1,
#           'usłyszał': 2,
#           'wyprostował': 1,
#           'przyjechał': 1,
#           'zapytał': 3,
#           'zastanowił': 1,
#           'skończył': 2,
#           'starannie': 1,
#           'meade': 3,
#           'dodał': 1,
#           'mieli': 1,
#           'zmarł': 1,
#           'chyba': 3,
#           'wstrzymał': 1,
#           'sam': 1,
#           'krzaczaste': 1,
#           'chwycił': 4,
#           'po': 1,
#           'widział': 4,
#           'ten': 2,
#           'zamilkł': 1,
#           'potrzebował': 1,
#           'może': 2,
#           'przysiadł': 1,
#           'milczał': 1,
#           'to': 8,
#           'skrzywił': 3,
#           'dam': 1,
#           'wtrąciła': 1,
#           'otworzył': 4,
#           'widzieli': 1,
#           'wszyscy': 3,
#           'odpowiedź': 1,
#           'upewnił': 1,
#           'tak': 1,
#           'oblizał': 1,
#           'go': 1,
#           'starając': 1,
#           'pszczół': 1,
#           'odsunął': 2,
#           'widuje': 1,
#           'wskazał': 2,
#           'obejrzał': 2,
#           'zrobił': 2,
#           'pomyłkowo': 1,
#           'raz': 1,
#           'obrócił': 2,
#           'właśnie': 1,
#           'zignorował': 2,
#           'jechał': 3,
#           'wyszedł': 1,
#           'zamknął': 2,
#           'stanął': 1,
#           'szybko': 1,
#           'rozciągnął': 1,
#           'panie': 1,
#           'słyszy': 1,
#           'siadając': 1,
#           'wolno': 3,
#           'minął': 2,
#           'i': 7,
#           'oblał': 1,
#           'wjechał': 1,
#           'rzucił': 1,
#           'mocno': 1,
#           'zamrugał': 4,
#           'sobie': 1,
#           'skinął': 1,
#           'opadł': 1,
#           'wykonał': 2,
#           'potem': 1,
#           'pochylił': 1,
#           'coś': 3,
#           'oddychał': 1,
#           'kiedy': 1,
#           'podążył': 1,
#           'za': 1,
#           'sprzedaż': 1,
#           'podniósł': 3,
#           'oni': 1,
#           'trzymam': 1,
#           'wysączył': 1,
#           'chcę': 1,
#           'dyskretnie': 1,
#           'klęczał': 1,
#           'oparł': 1,
#           'lecz': 1,
#           'wymruczał': 1,
#           'już': 2,
#           'poczuł': 3,
#           'czuł': 1,
#           'pokiwał': 2,
#           'zaczynał': 1,
#           'uświadamiając': 1,
#           'wyciągnął': 1,
#           'wyjął': 1,
#           'odstawił': 1,
#           'muszę': 2,
#           'spłukał': 1,
#           'wytarł': 2,
#           'przykucnął': 1,
#           'wziął': 1,
#           'spojrzał': 3,
#           'ponownie': 1,
#           'tkwił': 1,
#           'zadrżał': 1,
#           'wytężył': 1,
#           'koncentrował': 1,
#           'przywrócił': 1,
#           'oklapł': 1,
#           'myślę': 1,
#           'przyjął': 1,
#           'niecierpliwie': 1,
#           'kierując': 1,
#           'przyśpieszając': 1,
#           'zamyślił': 1,
#           'doszedł': 1,
#           'czując': 1,
#           'przytłumionym': 1,
#           'dostrzegł': 2,
#           'pobiegł': 1,
#           'machając': 1,
#           'zaś': 1,
#           'który': 1,
#           'ustalił': 1,
#           'wyszczerzył': 1,
#           'postukał': 1,
#           'trzymał': 1,
#           'rozumiejąc': 1,
#           'wszędzie': 1,
#           'pańska': 1,
#           'rozumiem': 1,
#           'wiem': 1,
#           'wędrowcy': 1,
#           'dlaczego': 1,
#           'wyjrzał': 1,
#           'okno': 1,
#           'według': 2,
#           'aryman': 1,
#           'sprężył': 1,
#           'jeśli': 1,
#           'stwierdził': 2,
#           'poprawia': 1,
#           'przypominam': 1,
#           'sprawię': 1,
#           'wrócił': 1,
#           'ktoś': 2,
#           'pracowaliśmy': 1,
#           'zwilżył': 1,
#           'chodził': 1,
#           'kto': 1,
#           'zajął': 1,
#           'udało': 1,
#           'odchylił': 1,
#           'jak': 2,
#           'w': 1,
#           'cofnął': 1,
#           'podbiegł': 1,
#           'złapał': 1,
#           'rozejrzał': 1,
#           'zapomniał': 1,
#           'była': 1,
#           'rozdeptywał': 1,
#           'uciekał': 1,
#           'odskoczył': 1,
#           'cisnął': 1,
#           'zapiszczał': 1,
#           'spróbował': 1,
#           'zbiegł': 1,
#           'dotarł': 1,
#           'uniósł': 1,
#           'szarpnął': 1,
#           'zaskrzeczał': 1,
#           'patrzył': 1,
#           'skoncentrował': 1,
#           'rozumie': 1,
#           'zakręcił': 1,
#           'zatoczył': 1,
#           'wpełzł': 1,
#           'rozległ': 2,
#           'kucnął': 1,
#           'zawołał': 1,
#           'sapnął': 1,
#           'będziesz': 1,
#           'niewiele': 1,
#           'chrząknął': 1,
#           'dotknęła': 1,
#           'postawił': 1,
#           'zaczęli': 1,
#           'ubawiony': 1,
#           'u': 1,
#           'uśmiechając': 1,
#           'zdziwiony': 1,
#           'no': 1,
#           'zamierza': 1,
#           'myślał': 1,
#           'uśmiechnąwszy': 1,
#           'ruszając': 1,
#           'usadowił': 1,
#           'westchnął': 1}),
#  'peggy, barton, mam': Counter({'już': 1, '#sum': 1}),
#  'mam': Counter({'już': 6,
#           '#sum': 35,
#           'nadzieję': 2,
#           'swoje': 3,
#           'władzę': 1,
#           'tu': 1,
#           'przytaknął': 1,
#           'około': 1,
#           'rację': 1,
#           'tego': 1,
#           'dosyć': 1,
#           'tam': 1,
#           'problemów': 1,
#           'teraz': 1,
#           'i': 1,
#           'zdjęcia': 1,
#           'dość': 1,
#           'dobrą': 1,
#           'zacząć': 1,
#           'odparł': 1,
#           'konkretną': 1,
#           'żadnego': 1,
#           'pomysł': 1,
#           'ważne': 1,
#           'powiedzieć': 1,
#           'wam': 1,
#           'za': 1,
#           'odparła': 1}),
#  'barton, mam, już': Counter({'dosyć': 1, '#sum': 1}),
#  'mam, już, dosyć': Counter({'odwróciła': 1,
#           '#sum': 5,
#           'słuchania': 1,
#           'już': 1,
#           'powiedział': 1,
#           'na': 1}),
#  'dosyć': Counter({'odwróciła': 1,
#           '#sum': 8,
#           'słuchania': 1,
#           'już': 1,
#           'pieniędzy': 1,
#           'powiedział': 1,
#           'kłopotów': 1,
#           'na': 1,
#           'mocy': 1}),
#  'już, dosyć, odwróciła': Counter({'się': 1, '#sum': 1}),
#  'odwróciła': Counter({'się': 2, '#sum': 2}),
#  'dosyć, odwróciła, się': Counter({'i': 1, '#sum': 1}),
#  'odwróciła, się, i': Counter({'zaczęła': 1, '#sum': 1}),
#  'się, i, zaczęła': Counter({'grzebać': 1, '#sum': 1}),
#  'zaczęła': Counter({'grzebać': 1,
#           '#sum': 12,
#           'je': 1,
#           'niknąć': 2,
#           'pojawiać': 1,
#           'się': 4,
#           'formować': 1,
#           'odczuwać': 1,
#           'uciekać': 1}),
#  'i, zaczęła, grzebać': Counter({'za': 1, '#sum': 1}),
#  'grzebać': Counter({'za': 1, '#sum': 1}),
#  'zaczęła, grzebać, za': Counter({'siedzeniem': 1, '#sum': 1}),
#  'grzebać, za, siedzeniem': Counter({'szukając': 1, '#sum': 1}),
#  'siedzeniem': Counter({'szukając': 1, '#sum': 1}),
#  'za, siedzeniem, szukając': Counter({'puszki': 1, '#sum': 1}),
#  'szukając': Counter({'puszki': 1,
#           '#sum': 6,
#           'po': 1,
#           'swojego': 1,
#           'jakiejś': 1,
#           'jej': 1,
#           'mary': 1}),
#  'siedzeniem, szukając, puszki': Counter({'piwa': 1, '#sum': 1}),
#  'puszki': Counter({'piwa': 1, '#sum': 3, 'farby': 1, 'z': 1}),
#  'szukając, puszki, piwa': Counter({'piwo': 1, '#sum': 1}),
#  'piwa': Counter({'piwo': 1, '#sum': 3, 'w': 1, 'zniknął': 1}),
#  'puszki, piwa, piwo': Counter({'było': 1, '#sum': 1}),
#  'piwo': Counter({'było': 1, '#sum': 1}),
#  'piwa, piwo, było': Counter({'ciepłe': 1, '#sum': 1}),
#  'było': Counter({'ciepłe': 1,
#           '#sum': 138,
#           'misterną': 1,
#           'mu': 3,
#           'tylko': 3,
#           'chłodno': 1,
#           'na': 4,
#           'ulicy': 1,
#           'sklep': 1,
#           'to': 5,
#           'tam': 2,
#           'pokręcone': 1,
#           'jej': 3,
#           'w': 4,
#           'peter': 1,
#           'jego': 3,
#           'musiał': 1,
#           'jedyne': 1,
#           'barton': 2,
#           'że': 4,
#           'już': 4,
#           'gorąco': 1,
#           'stęchliznę': 1,
#           'dokładnie': 1,
#           'gdyby': 1,
#           'ostrzeżenie': 1,
#           'tak': 1,
#           'jeszcze': 2,
#           'między': 1,
#           'nie': 3,
#           'słychać': 1,
#           'jak': 4,
#           'nas': 1,
#           'właśnie': 1,
#           'nikogo': 2,
#           'pogrążone': 1,
#           'coś': 2,
#           'swego': 1,
#           'niebieskoszarą': 1,
#           'widać': 3,
#           'oczywiste': 2,
#           'a': 1,
#           'tego': 1,
#           'zimno': 1,
#           'zmienione': 1,
#           'tyle': 1,
#           'tu': 2,
#           'nieszczególne': 1,
#           'jakieś': 1,
#           'butelki': 1,
#           'łatwo': 1,
#           'bardzo': 2,
#           'dla': 2,
#           'pana': 1,
#           'przed': 1,
#           'co': 1,
#           'stare': 1,
#           'wyraz': 1,
#           'twarde': 1,
#           'popełnić': 1,
#           'jednak': 2,
#           'opuszczone': 1,
#           'wyczerpane': 1,
#           'my': 1,
#           'dobre': 1,
#           'zabawne': 1,
#           'jednym': 1,
#           'go': 1,
#           'mruknął': 1,
#           'wyjechałem': 1,
#           'mnie': 1,
#           'życia': 1,
#           'golemem': 1,
#           'żadnego': 1,
#           'ich': 1,
#           'zgadza': 1,
#           'wszystko': 1,
#           'kiedyś': 1,
#           'bez': 1,
#           'smród': 1,
#           'innego': 1,
#           'przerażenie': 1,
#           'masywne': 1,
#           'dziwne': 2,
#           'nic': 1,
#           'ziemi': 1,
#           'śledzić': 1,
#           'gdzie': 1,
#           'reakcji': 1,
#           'najlepsze': 1,
#           'chyba': 1,
#           'był': 1,
#           'zniknęła': 1,
#           'odcięte': 1,
#           'teraz': 1,
#           'millgate': 1,
#           'jedynie': 1}),
#  'piwo, było, ciepłe': Counter({'wrzuciła': 1, '#sum': 1}),
#  'ciepłe': Counter({'wrzuciła': 1, '#sum': 3, 'wino': 1, 'mary': 1}),
#  'było, ciepłe, wrzuciła': Counter({'je': 1, '#sum': 1}),
#  'wrzuciła': Counter({'je': 1, '#sum': 1}),
#  'ciepłe, wrzuciła, je': Counter({'do': 1, '#sum': 1}),
#  'je': Counter({'do': 2,
#           '#sum': 68,
#           'kiedykolwiek': 1,
#           'wszedł': 1,
#           'obie': 1,
#           'bez': 1,
#           'zadawać': 1,
#           'rzucił': 1,
#           'w': 3,
#           'ogrodzić': 1,
#           'ogrodzili': 1,
#           'słyszałem': 1,
#           'podała': 1,
#           'nie': 2,
#           'kiedyś': 1,
#           'żuć': 1,
#           'pamiętałem': 1,
#           'i': 4,
#           'na': 4,
#           'często': 1,
#           'obserwuje': 1,
#           'bartonowi': 1,
#           'oddać': 1,
#           'wytarł': 1,
#           'dlaczego': 1,
#           'opuścić': 1,
#           'odwrócić': 1,
#           'pamiętam': 1,
#           'christopher': 1,
#           'jego': 1,
#           'ściąć': 1,
#           'co': 1,
#           'stworzyli': 1,
#           'tylko': 1,
#           'szary': 1,
#           'przenikać': 1,
#           'takim': 1,
#           'skorygować': 1,
#           'z': 4,
#           'mroczną': 1,
#           'hałaśliwie': 1,
#           'odgolemiło': 1,
#           'wypuścił': 1,
#           'jest': 1,
#           'poprawił': 1,
#           'rozproszone': 1,
#           'ormuzd': 1,
#           'stać': 1,
#           'otworzyć': 1,
#           'biegnąc': 1,
#           'zamknął': 1,
#           'złapać': 1,
#           'odpędzić': 1,
#           'było': 1,
#           'po': 1,
#           'wolno': 1}),
#  'wrzuciła, je, do': Counter({'torby': 1, '#sum': 1}),
#  'je, do, torby': Counter({'i': 1, '#sum': 1}),
#  'torby': Counter({'i': 1, '#sum': 2, 'podróżne': 1}),
#  'do, torby, i': Counter({'usadowiwszy': 1, '#sum': 1}),
#  'torby, i, usadowiwszy': Counter({'się': 1, '#sum': 1}),
#  'usadowiwszy': Counter({'się': 1, '#sum': 1}),
#  'i, usadowiwszy, się': Counter({'z': 1, '#sum': 1}),
#  'usadowiwszy, się, z': Counter({'powrotem': 1, '#sum': 1}),
#  'się, z, powrotem': Counter({'w': 1,
#           '#sum': 3,
#           'rozpaczliwie': 1,
#           'wynurzył': 1}),
#  'z, powrotem, w': Counter({'fotelu': 1, '#sum': 1}),
#  'powrotem, w, fotelu': Counter({'oparła': 1, '#sum': 1}),
#  'fotelu': Counter({'oparła': 1, '#sum': 3, 'wyprostował': 1, 'powrót': 1}),
#  'w, fotelu, oparła': Counter({'się': 1, '#sum': 1}),
#  'oparła': Counter({'się': 1, '#sum': 1}),
#  'fotelu, oparła, się': Counter({'o': 1, '#sum': 1}),
#  'oparła, się, o': Counter({'drzwi': 1, '#sum': 1}),
#  'się, o, drzwi': Counter({'zakładając': 1, '#sum': 1}),
#  'o, drzwi, zakładając': Counter({'ze': 1, '#sum': 1}),
#  'zakładając': Counter({'ze': 1, '#sum': 1}),
#  'drzwi, zakładając, ze': Counter({'złością': 1, '#sum': 1}),
#  'zakładając, ze, złością': Counter({'ręce': 1, '#sum': 1}),
#  'złością': Counter({'ręce': 1,
#           '#sum': 6,
#           'cóż': 1,
#           'walter': 1,
#           'i': 1,
#           'barton': 1,
#           'to': 1}),
#  'ze, złością, ręce': Counter({'na': 1, '#sum': 1}),
#  'złością, ręce, na': Counter({'piersi': 1, '#sum': 1}),
#  'ręce, na, piersi': Counter({'kropelki': 1,
#           '#sum': 4,
#           'cześć': 1,
#           'skoncentrował': 1,
#           'i': 1}),
#  'na, piersi, kropelki': Counter({'potu': 1, '#sum': 1}),
#  'kropelki': Counter({'potu': 2, '#sum': 2}),
#  'piersi, kropelki, potu': Counter({'spływały': 1, '#sum': 1}),
#  'potu': Counter({'spływały': 2, '#sum': 2}),
#  'kropelki, potu, spływały': Counter({'jej': 1, '#sum': 2, 'po': 1}),
#  'spływały': Counter({'jej': 1, '#sum': 2, 'po': 1}),
#  ...}

# %%
order = 3
author_chains = Counter()
author_chains['global'] = {}
for author, book in train_set:
    if author not in author_chains:
        author_chains[author] = {} 
    author_chains[author] = build_markov_chain(author_chains[author],os.path.join(test_dir, book), order)
    # calculate global through reference
    author_chains['global'] = build_markov_chain(author_chains['global'],os.path.join(test_dir, book), order)

# %%
author_chains['global']
# Out:
# {'philip, k': Counter({'dick': 6, '#sum': 6}),
#  'k': Counter({'dick': 6,
#           '#sum': 70,
#           'stuknięty': 1,
#           'edy': 1,
#           'ohl': 9,
#           'tze': 1,
#           'me': 1,
#           'nie': 1,
#           'cisza': 1,
#           'u': 4,
#           'a': 9,
#           'n': 4,
#           'o': 6,
#           'i': 5,
#           'r': 4,
#           'dobrze': 1,
#           'j': 1,
#           'l': 2,
#           'c': 1,
#           'ą': 1,
#           'w': 3,
#           'z': 2,
#           'który': 1,
#           'profesor': 1,
#           'cyberleutnant': 1,
#           'czyli': 1,
#           'do': 1,
#           'zmieniona': 1}),
#  'k, dick': Counter({'trzy': 1,
#           '#sum': 6,
#           'pani': 1,
#           'galaktyczny': 1,
#           '1969': 1,
#           'paszcza': 1,
#           'za': 1}),
#  'dick': Counter({'trzy': 1,
#           '#sum': 14,
#           'pani': 1,
#           'galaktyczny': 1,
#           '1969': 1,
#           'paszcza': 1,
#           'za': 1,
#           'o': 3,
#           'greg': 1,
#           'nalał': 1,
#           'zaskrzeczała': 1,
#           'pieprz': 1,
#           'wrzasnęła': 1}),
#  'dick, trzy': Counter({'stygmaty': 1, '#sum': 1}),
#  'trzy': Counter({'stygmaty': 2,
#           '#sum': 473,
#           'czwarte': 7,
#           'mieszkanki': 1,
#           'satelity': 1,
#           'dni': 32,
#           'za': 1,
#           'pary': 3,
#           'kwadranse': 1,
#           'na': 2,
#           'szpitale': 1,
#           'planety': 1,
#           'lata': 24,
#           'stulecia': 1,
#           'główne': 1,
#           'godziny': 17,
#           'mnożone': 1,
#           'dłonie': 1,
#           'minuty': 8,
#           'osoby': 2,
#           'spośród': 1,
#           'centy': 3,
#           'centowe': 1,
#           'i': 4,
#           'już': 1,
#           'gatunki': 1,
#           'stopnie': 4,
#           'wielkie': 3,
#           'manego': 1,
#           'świstki': 1,
#           'pierwsze': 1,
#           'razy': 12,
#           'wszyscy': 1,
#           'zestawy': 2,
#           'hermetycznie': 1,
#           'gdyby': 1,
#           'oznacza': 1,
#           'onz': 1,
#           'tygodnie': 10,
#           'dolary': 4,
#           'właśnie': 1,
#           'warstwy': 1,
#           'stopy': 5,
#           'palce': 1,
#           'słowa': 2,
#           'grosy': 1,
#           'kamienie': 1,
#           'kiełbaski': 1,
#           'stowarzyszenia': 1,
#           'łyżeczki': 1,
#           'córki': 1,
#           'cale': 4,
#           'do': 3,
#           'ale': 2,
#           'postacie': 2,
#           'b': 1,
#           'c': 1,
#           'może': 1,
#           'piwa': 3,
#           'zasady': 2,
#           'maleńkie': 1,
#           'cholerne': 1,
#           'z': 4,
#           'dodał': 1,
#           'teorie': 1,
#           'choć': 1,
#           'kociopodobne': 1,
#           'taczki': 1,
#           'jeśli': 1,
#           'zniknęły': 1,
#           'spokojna': 1,
#           'klepsydry': 1,
#           'narciarskie': 1,
#           'tak': 1,
#           'karty': 1,
#           'solidne': 1,
#           'inne': 1,
#           'kubki': 1,
#           'ośmiościenne': 1,
#           'zapewnił': 1,
#           'cztery': 4,
#           'próby': 1,
#           'wojny': 1,
#           'miedziaki': 1,
#           'przypadki': 1,
#           'moje': 1,
#           'pióra': 1,
#           'miejsca': 1,
#           'życzenia': 5,
#           'delikatne': 1,
#           'oznaki': 1,
#           'tysiące': 4,
#           'rzeczy': 4,
#           'miliardy': 5,
#           'rasy': 1,
#           'płcie': 3,
#           'nie': 2,
#           'kości': 1,
#           'szóstki': 2,
#           'zdecydował': 1,
#           'dokończył': 1,
#           'szczeniaki': 1,
#           'ładowania': 1,
#           'po': 2,
#           'mile': 2,
#           'sandwicze': 1,
#           'percy': 1,
#           'miesiące': 7,
#           'życia': 1,
#           'siódma': 1,
#           'albo': 2,
#           'pagórki': 1,
#           'krzyże': 1,
#           'w': 2,
#           'żarówki': 1,
#           'hot': 1,
#           'listy': 1,
#           'dziewczyny': 1,
#           'dziesiątki': 1,
#           'przecznice': 1,
#           'samochody': 1,
#           'nowe': 2,
#           'vera': 1,
#           'foliowe': 1,
#           'dziesięciocentówki': 1,
#           'pręty': 1,
#           'kilometry': 1,
#           'metry': 2,
#           'gumy': 1,
#           'operacje': 2,
#           'zdjęcia': 2,
#           'walizki': 2,
#           'kroki': 2,
#           'pompki': 1,
#           'sekundy': 2,
#           'dwie': 1,
#           'pielęgniarki': 1,
#           'czy': 2,
#           'miliony': 4,
#           'materiały': 1,
#           'niczym': 1,
#           'procent': 2,
#           'były': 1,
#           'duże': 3,
#           'zeszyty': 1,
#           'książki': 1,
#           'przyłożenia': 1,
#           'ćwierćdolarówki': 1,
#           'starsze': 1,
#           'narody': 1,
#           'jej': 1,
#           'latka': 2,
#           'przy': 1,
#           'kręgi': 1,
#           'skręty': 1,
#           'pokolenia': 1,
#           'głosy': 3,
#           'miejskie': 1,
#           'ciała': 1,
#           'tabletki': 1,
#           'jednocześnie': 1,
#           'udręczone': 1,
#           'obok': 1,
#           'wozy': 1,
#           'śmierci': 1,
#           'dożywocia': 1,
#           'kawałki': 1,
#           'cudowne': 1,
#           'puszki': 1,
#           'dowody': 1,
#           'panie': 1,
#           'tuziny': 1,
#           'dla': 1,
#           'złamane': 1,
#           'kielonki': 1,
#           'rodzaje': 2,
#           'przednie': 1,
#           'sposoby': 2,
#           'ołówki': 1,
#           'lub': 1,
#           'jednodolarówki': 1,
#           'łóżka': 1,
#           'świeczki': 1,
#           'siostry': 1,
#           'ocalałe': 1,
#           'pacierze': 3,
#           'noce': 1,
#           'związane': 1,
#           'kobiety': 2,
#           'czarne': 2,
#           'kawki': 46,
#           'kolory': 1,
#           'dzbanki': 1,
#           'ćwierci': 1,
#           'końskie': 1,
#           'smoki': 1,
#           'szczerbate': 1,
#           'wąskie': 1,
#           'wyjścia': 1,
#           'kaw': 1,
#           'myszy': 1,
#           'drzewa': 1,
#           'pnie': 2,
#           'kąty': 1,
#           'okna': 2,
#           'trzy': 1,
#           'istoty': 1,
#           'szafy': 1,
#           'rakiety': 1,
#           'ich': 1,
#           'kolejne': 2,
#           'mał': 1,
#           'olbrzymie': 1,
#           'mać': 2,
#           'komory': 1,
#           'porody': 1,
#           'wypełnione': 1,
#           'części': 1,
#           'przeciw': 1,
#           'j': 1,
#           'dekady': 1,
#           'dalsze': 1,
#           'cienkie': 1,
#           'takie': 1,
#           'fakultety': 1,
#           'wersje': 1,
#           'a': 1,
#           'nikomu': 1,
#           'państwa': 1,
#           'jednostki': 1,
#           'leki': 1}),
#  'trzy, stygmaty': Counter({'palmera': 1, '#sum': 2, 'martwą': 1}),
#  'stygmaty': Counter({'palmera': 1,
#           '#sum': 5,
#           'przez': 1,
#           'martwą': 1,
#           'nie': 1,
#           'widzenia': 1}),
#  'stygmaty, palmera': Counter({'eldritcha': 1, '#sum': 1}),
#  'palmera': Counter({'eldritcha': 63,
#           '#sum': 67,
#           'doszedł': 1,
#           'jak': 1,
#           'że': 1,
#           'ponieważ': 1}),
#  'palmera, eldritcha': Counter({'przełożył': 1,
#           '#sum': 63,
#           'który': 2,
#           'ach': 1,
#           'po': 1,
#           'wtedy': 1,
#           'to': 2,
#           'przez': 1,
#           'najwidoczniej': 1,
#           'tak': 1,
#           'oczywiście': 1,
#           'wielki': 1,
#           'powiedział': 1,
#           'wydarzeniach': 1,
#           'prawda': 1,
#           'barney': 1,
#           'czy': 1,
#           'jeżeli': 1,
#           'oddałeś': 1,
#           'pańskie': 1,
#           'nagle': 1,
#           'ty': 1,
#           'aby': 1,
#           'na': 2,
#           'jest': 2,
#           'a': 2,
#           'celowo': 1,
#           'jeśli': 1,
#           'czemu': 1,
#           'jesteś': 1,
#           'odwrócił': 1,
#           'mógł': 1,
#           'zrobię': 1,
#           'nie': 1,
#           'chce': 1,
#           'przecież': 1,
#           'pogadałem': 1,
#           'łamię': 1,
#           'jestem': 1,
#           'teraz': 1,
#           'zakończyła': 1,
#           'jak': 1,
#           'zapytywał': 1,
#           'i': 4,
#           'co': 1,
#           'kryje': 1,
#           'oplatane': 1,
#           'gdzie': 1,
#           'annę': 1,
#           'rybaka': 1,
#           'ale': 1,
#           'śmierć': 1,
#           'było': 1,
#           'już': 1,
#           'w': 2}),
#  'eldritcha': Counter({'przełożył': 1,
#           '#sum': 114,
#           'który': 4,
#           'już': 2,
#           'dla': 1,
#           'twierdzą': 1,
#           'ach': 1,
#           'po': 1,
#           'porozmawia': 1,
#           'wtedy': 1,
#           'gdy': 1,
#           'to': 4,
#           'przez': 1,
#           'chociaż': 1,
#           'santina': 1,
#           'najwidoczniej': 1,
#           'tak': 3,
#           'jak': 3,
#           'oczywiście': 1,
#           'wielki': 1,
#           'powiedział': 2,
#           'wydarzeniach': 1,
#           'prawda': 1,
#           'barney': 1,
#           'czy': 3,
#           'nic': 1,
#           'jeżeli': 1,
#           'oddałeś': 1,
#           'pańskie': 1,
#           'nagle': 1,
#           'karty': 1,
#           'ty': 1,
#           'aby': 1,
#           'mogę': 1,
#           'na': 5,
#           'stwór': 1,
#           'życzyłem': 1,
#           'jest': 2,
#           'a': 2,
#           'wciąż': 1,
#           'celowo': 1,
#           'jeśli': 1,
#           'śmiercią': 1,
#           'leo': 1,
#           'czemu': 1,
#           'alec': 1,
#           'jesteś': 1,
#           'odwrócił': 1,
#           'jego': 1,
#           'chew': 1,
#           'mógł': 1,
#           'zrobię': 1,
#           'nie': 1,
#           'i': 6,
#           'zmarszczył': 1,
#           'chce': 1,
#           'przecież': 1,
#           'co': 2,
#           'pogadałem': 1,
#           'położywszy': 1,
#           'łamię': 1,
#           'była': 1,
#           'jestem': 1,
#           'teraz': 1,
#           'zaledwie': 1,
#           'ja': 1,
#           'zakończyła': 1,
#           'chciał': 1,
#           'zapytywał': 1,
#           'nałożony': 1,
#           'eldritch': 1,
#           'opiera': 1,
#           'wylądował': 1,
#           'kryje': 1,
#           'oplatane': 1,
#           'gdzie': 1,
#           'wiesz': 1,
#           'no': 1,
#           'annę': 1,
#           'rybaka': 1,
#           'nad': 1,
#           'zmieniające': 1,
#           'mimo': 1,
#           'ale': 1,
#           'śmierć': 1,
#           'było': 1,
#           'przed': 1,
#           'w': 2}),
#  'eldritcha, przełożył': Counter({'zbigniew': 1, '#sum': 1}),
#  'przełożył': Counter({'zbigniew': 2,
#           '#sum': 13,
#           'z': 1,
#           'cezary': 1,
#           'piotr': 1,
#           'jarosław': 1,
#           'pas': 1,
#           'krzysztof': 1,
#           'wszystkie': 1,
#           'je': 1,
#           'radosław': 1,
#           'siekierę': 1,
#           'nad': 1}),
#  'przełożył, zbigniew': Counter({'królicki': 1, '#sum': 2, 'a': 1}),
#  'zbigniew': Counter({'królicki': 1, '#sum': 2, 'a': 1}),
#  'zbigniew, królicki': Counter({'1': 1, '#sum': 1}),
#  'królicki': Counter({'1': 1, '#sum': 2, 'sądzę': 1}),
#  'królicki, 1': Counter({'barney': 1, '#sum': 1}),
#  '1': Counter({'barney': 1,
#           '#sum': 71,
#           '46': 1,
#           'jeśli': 1,
#           'lepiej': 1,
#           'jak': 1,
#           'nic': 1,
#           'co': 4,
#           'wszystkojeeest': 1,
#           'wypoleruję': 1,
#           'nie': 2,
#           'jeszcze': 1,
#           'magicznych': 1,
#           'kopnie': 1,
#           'bardzo': 1,
#           'postępują': 1,
#           'podziękowałem': 1,
#           'to': 3,
#           'popularna': 1,
#           'cisza': 1,
#           '67563': 1,
#           'praktycznie': 1,
#           'w': 6,
#           'można': 1,
#           'egzemplarzu': 1,
#           'spróbuj': 1,
#           'tak': 1,
#           'wetmore': 1,
#           'ą': 1,
#           'e': 1,
#           'herbert': 1,
#           'września': 1,
#           'portsmouth': 1,
#           '15': 1,
#           'i': 5,
#           'lipca': 1,
#           'użyć': 1,
#           'powrót': 2,
#           'rozgorzały': 1,
#           'wszystkie': 1,
#           'ostatnio': 1,
#           'hello': 1,
#           'od': 1,
#           'roboty': 1,
#           'logiom': 1,
#           'poniższe': 1,
#           'rozmyślnie': 1,
#           'przeżywamy': 1,
#           'mniej': 1,
#           'długo': 1,
#           'poniższy': 1,
#           'tytuł': 1,
#           'drugim': 1,
#           'życiorys': 1,
#           'nanotechnologie': 1,
#           'poznajemy': 1}),
#  '1, barney': Counter({'mayerson': 1, '#sum': 1}),
#  'barney': Counter({'mayerson': 34,
#           '#sum': 381,
#           'i': 12,
#           'przygładzając': 1,
#           'ma': 1,
#           'wszedł': 3,
#           'robiąc': 1,
#           'stwierdził': 1,
#           'uważasz': 2,
#           'tak': 2,
#           'chyba': 1,
#           'zapytał': 2,
#           'mógł': 1,
#           'zmrużył': 1,
#           'zmarszczył': 1,
#           'niechętnie': 1,
#           'spojrzał': 2,
#           'bezbarwnym': 1,
#           'powiedział': 4,
#           'poczerwieniał': 1,
#           'pogrożę': 1,
#           'natychmiast': 1,
#           'obrzucił': 1,
#           'to': 6,
#           'kiwnął': 1,
#           'mój': 1,
#           'musi': 2,
#           'ze': 2,
#           'był': 6,
#           'dzięki': 1,
#           'wziął': 2,
#           'dał': 1,
#           'na': 1,
#           'niebawem': 1,
#           'a': 5,
#           'wzruszył': 4,
#           'cztery': 1,
#           'nazywanego': 1,
#           'pogwałciłem': 1,
#           'właśnie': 2,
#           'zapomniałem': 1,
#           'dotyczą': 1,
#           'poczynił': 1,
#           'ja': 5,
#           'zrezygnuję': 1,
#           'nic': 2,
#           'rób': 1,
#           'możemy': 1,
#           'od': 1,
#           'rozumiem': 1,
#           'miał': 1,
#           'rozłączył': 2,
#           'instynkt': 1,
#           'że': 8,
#           'wiedział': 1,
#           'opuścił': 1,
#           'wracający': 1,
#           'nie': 17,
#           'spojrzałem': 1,
#           'ponieważ': 2,
#           'wyprawiał': 1,
#           'prawda': 1,
#           'wyciągnął': 1,
#           'wyszedł': 2,
#           'wylał': 1,
#           'nadjechała': 1,
#           'postradałaś': 1,
#           'jeśli': 3,
#           'podszedł': 2,
#           'pomyślał': 2,
#           'odłożył': 1,
#           'przyspiesz': 1,
#           'pan': 1,
#           'mikrofon': 1,
#           'odezwał': 1,
#           'dlaczego': 1,
#           'poważne': 1,
#           'myślę': 1,
#           'czy': 5,
#           'popełniają': 1,
#           'popełniamy': 1,
#           'zaprzestając': 1,
#           'spędzę': 1,
#           'wstał': 1,
#           'potrząsnął': 1,
#           'w': 7,
#           'wyjaśnij': 1,
#           'przykro': 1,
#           'może': 5,
#           'taak': 1,
#           'zrozumiał': 1,
#           'który': 1,
#           'naprawdę': 3,
#           'chrystus': 1,
#           'ale': 3,
#           'kiedy': 1,
#           'czytał': 1,
#           'zerknął': 1,
#           'siadając': 1,
#           'wyjął': 1,
#           'dotyczy': 1,
#           'odmówił': 1,
#           'pług': 1,
#           'sięgnął': 1,
#           'trzy': 1,
#           'impatience': 1,
#           'pozostał': 1,
#           'zaczął': 1,
#           'uważamy': 1,
#           'mówiąc': 1,
#           'więc': 1,
#           'zaczai': 2,
#           'za': 2,
#           'kolonia': 1,
#           'zauważył': 1,
#           'powiedziała': 7,
#           'zaczekaj': 1,
#           'uświadomił': 2,
#           'wszyscy': 2,
#           'helen': 1,
#           'pewnie': 1,
#           'sięgając': 1,
#           'domyślał': 1,
#           'oni': 1,
#           'czuję': 1,
#           'wydało': 1,
#           'musiałabym': 1,
#           'chcę': 1,
#           'lecz': 1,
#           'gdzie': 1,
#           'przycisnął': 1,
#           'z': 1,
#           'upiorne': 1,
#           'było': 1,
#           'słucham': 1,
#           'co': 2,
#           'dam': 1,
#           'wyglądało': 1,
#           '1': 1,
#           'epilepsja': 1,
#           'faine': 2,
#           'gdyby': 1,
#           'klasyczna': 1,
#           'myślał': 3,
#           'przypuszczał': 1,
#           'po': 1,
#           'machinalnie': 1,
#           'wydobywa': 1,
#           'zdał': 1,
#           'zeszłej': 1,
#           'eldritch': 2,
#           'odwrócił': 2,
#           'poczuł': 2,
#           'patrzył': 2,
#           'zamknął': 1,
#           'zaczęła': 1,
#           'byłbym': 1,
#           'obrócił': 1,
#           'jest': 1,
#           'dostrzegł': 1,
#           'sadowiąc': 1,
#           'spytała': 1,
#           'zapomniana': 1,
#           'szaleństwo': 1,
#           'palmer': 1,
#           'ujrzał': 1,
#           'otworzył': 1,
#           'tuż': 1,
#           'annę': 1,
#           'szybko': 1,
#           'oto': 1,
#           'przed': 1,
#           'umilkł': 1,
#           'wyłączył': 1,
#           'leć': 1,
#           'bał': 1,
#           'też': 1,
#           'znalazł': 1,
#           'zażył': 2,
#           'posłużył': 1,
#           'felix': 1,
#           'wiesz': 1,
#           'szok': 1,
#           'jestem': 1,
#           'biorę': 1,
#           'zacisnął': 1,
#           'ty': 1,
#           'ruszył': 1,
#           'otwierając': 1,
#           'właściciel': 1,
#           'muszę': 1,
#           'jesteś': 1,
#           'odszedł': 1,
#           'przyjrzał': 1,
#           'już': 1,
#           'patrząc': 1,
#           'wspólnie': 1,
#           'najlepsze': 1,
#           'zostawię': 1,
#           'jednak': 1,
#           'barney': 1,
#           'była': 1,
#           'nawet': 1,
#           'jakoś': 1,
#           'mam': 1,
#           'roześmiał': 1,
#           'dobrze': 1,
#           'doprawić': 1,
#           'widział': 1,
#           'byłem': 1,
#           'rzekł': 1,
#           'nigdy': 2,
#           'jako': 1,
#           'słyszał': 1,
#           'powlókł': 1,
#           'miałem': 1,
#           'zaraz': 1,
#           'tego': 1,
#           'sposób': 1,
#           'coś': 1,
#           'aurę': 1,
#           'wyciągnęła': 1,
#           'gorączkowo': 1,
#           'zawrócił': 1,
#           'przeczuwał': 1,
#           'tkwił': 1,
#           'okręcił': 1,
#           'uwalniając': 1,
#           'usiadł': 1,
#           'wszedłszy': 1,
#           'nadal': 1,
#           'kto': 1,
#           'mówiło': 1,
#           'podniósł': 1,
#           'odzyskać': 1}),
#  'barney, mayerson': Counter({'zbudził': 1,
#           '#sum': 34,
#           'dalej': 1,
#           'powiedział': 2,
#           'zapytał': 1,
#           'teraz': 1,
#           'to': 1,
#           'powielali': 1,
#           'pracował': 1,
#           'wykorzystał': 1,
#           'był': 2,
#           'i': 2,
#           'skontaktuję': 1,
#           'człowiek': 1,
#           'zmęczony': 1,
#           'przedstawił': 1,
#           'rzekł': 1,
#           'z': 1,
#           'reszta': 1,
#           'jako': 1,
#           'podniósł': 1,
#           'spojrzeli': 1,
#           'obudź': 1,
#           'zamknął': 1,
#           'warunkujący': 1,
#           'ujrzał': 1,
#           'mayerson': 1,
#           'nie': 2,
#           'zmrużył': 1,
#           'usiadł': 1,
#           'leżał': 1}),
#  'mayerson': Counter({'zbudził': 1,
#           '#sum': 124,
#           'sprostował': 1,
#           'może': 5,
#           'i': 4,
#           'rzecz': 1,
#           'jest': 2,
#           'recepcjonistka': 1,
#           'za': 1,
#           'dalej': 1,
#           'był': 3,
#           'położywszy': 1,
#           'powiedział': 8,
#           'podniósł': 2,
#           'nie': 7,
#           'odezwała': 1,
#           'zapytał': 2,
#           'odparła': 1,
#           'wskazał': 1,
#           'przez': 1,
#           'teraz': 1,
#           'chciałby': 1,
#           'spytał': 3,
#           'to': 2,
#           'w': 2,
#           'słyszałem': 1,
#           'powielali': 1,
#           'pracował': 1,
#           'wykorzystał': 1,
#           'się': 1,
#           'uda': 1,
#           'tak': 3,
#           'jak': 1,
#           'sądzi': 1,
#           'wynika': 1,
#           'skontaktuję': 1,
#           'człowiek': 1,
#           'z': 5,
#           'zmęczony': 1,
#           'został': 1,
#           'przedstawił': 1,
#           'rzekł': 1,
#           'a': 1,
#           'będzie': 1,
#           'pragnienie': 1,
#           'zgłosiłem': 1,
#           'hmm': 2,
#           'jestem': 1,
#           'widzi': 1,
#           'poprawił': 1,
#           'próbowałem': 1,
#           'reszta': 1,
#           'mimo': 1,
#           'chciałam': 1,
#           'jako': 1,
#           'powiedziała': 1,
#           'barney': 1,
#           'mówię': 1,
#           'zanim': 1,
#           'mutacja': 1,
#           'wciąż': 1,
#           'świetna': 1,
#           'niebezpieczny': 1,
#           'zastanawiał': 1,
#           '1': 1,
#           'lepiej': 1,
#           'spojrzeli': 1,
#           'źle': 1,
#           'obudź': 1,
#           'zamknął': 1,
#           'warunkujący': 1,
#           'puść': 1,
#           'tym': 1,
#           'mówili': 1,
#           'ujrzał': 1,
#           'czy': 1,
#           'poczekaj': 1,
#           'mayerson': 1,
#           'przeniosę': 1,
#           'dokończył': 1,
#           'zmrużył': 1,
#           'usiadł': 1,
#           'leżał': 1,
#           'do': 1,
#           'no': 1,
#           'wygląda': 1,
#           'idę': 1,
#           'otwórz': 1,
#           'wiem': 1}),
#  'mayerson, zbudził': Counter({'się': 1, '#sum': 1}),
#  'zbudził': Counter({'się': 5, '#sum': 9, 'nie': 1, 'mnie': 2, '166': 1}),
#  'zbudził, się': Counter({'z': 1,
#           '#sum': 5,
#           'i': 1,
#           'leżał': 1,
#           'cichy': 1,
#           'zaszumiał': 1}),
#  'się': Counter({'z': 1414,
#           '#sum': 32238,
#           'w': 2278,
#           'do': 1293,
#           'zachwiał': 1,
#           'szybko': 37,
#           'śmieszny': 1,
#           'słyszeć': 11,
#           'powoli': 37,
#           'okropnie': 4,
#           'zgadza': 5,
#           'drzwi': 16,
#           'odrobinę': 12,
#           'po': 354,
#           'stało': 190,
#           'erotycznie': 1,
#           'wyciągnęła': 1,
#           'ubierać': 7,
#           'okazać': 19,
#           'pokazując': 3,
#           'szczebel': 2,
#           'jak': 250,
#           'rzekł': 9,
#           'niedaleko': 3,
#           'czy': 109,
#           'to': 363,
#           'system': 1,
#           'nowy': 5,
#           'zza': 18,
#           'kolejny': 8,
#           'o': 351,
#           'ku': 87,
#           'za': 265,
#           'tak': 248,
#           'pamiętał': 1,
#           'nie': 780,
#           'we': 69,
#           'na': 1595,
#           'spodziewałeś': 5,
#           'one': 17,
#           'czuł': 6,
#           'udać': 21,
#           'zbyt': 45,
#           'i': 744,
#           'pracochłonnym': 1,
#           'perky': 2,
#           'przeżyć': 3,
#           'że': 901,
#           'nazywa': 27,
#           'kiedy': 42,
#           'kierować': 1,
#           'pomyłki': 1,
#           'modne': 2,
#           'kilka': 10,
#           'wyprowadziła': 1,
#           'znowu': 44,
#           'paniom': 2,
#           'już': 197,
#           'pod': 146,
#           'mocniej': 2,
#           'panna': 4,
#           'naprawdę': 14,
#           'pan': 136,
#           'spodziewał': 5,
#           'zwrotu': 2,
#           'nigdy': 21,
#           'skończy': 23,
#           'can': 1,
#           'wszelkim': 2,
#           'pełen': 2,
#           'ich': 50,
#           'nakłonić': 1,
#           'może': 39,
#           'bezpośrednio': 4,
#           'chytrze': 1,
#           'a': 82,
#           'troską': 1,
#           'czując': 5,
#           'kończą': 2,
#           'co': 92,
#           'by': 44,
#           'leo': 12,
#           'jeszcze': 122,
#           'terapii': 3,
#           'sensacją': 2,
#           'barney': 9,
#           'powinna': 2,
#           'starzejesz': 1,
#           'podniósł': 5,
#           'tym': 103,
#           'widywać': 1,
#           'podczas': 11,
#           'od': 319,
#           'zasiedlić': 1,
#           'zachowałem': 1,
#           'sztućcami': 1,
#           'podrzucić': 1,
#           'coś': 66,
#           'pomóc': 4,
#           'mówi': 15,
#           'mniej': 15,
#           'wydawało': 16,
#           'zobaczyć': 6,
#           'rozłączył': 3,
#           'myśl': 2,
#           'przed': 103,
#           'trochę': 68,
#           'gdy': 18,
#           'nudne': 1,
#           'wokół': 79,
#           'stawały': 1,
#           'wrażenie': 8,
#           'doczekać': 9,
#           'urodził': 3,
#           'raz': 15,
#           'opłaciło': 2,
#           'dowiedzieć': 40,
#           'zamilkła': 1,
#           'myli': 8,
#           'panu': 23,
#           'wygodnie': 13,
#           'głosem': 3,
#           'tego': 86,
#           'tam': 142,
#           'dziecinnym': 1,
#           'zdarzyć': 20,
#           'paląc': 2,
#           'życiem': 1,
#           'początkiem': 1,
#           'błędne': 1,
#           'teraz': 85,
#           'wyrzucić': 1,
#           'znów': 12,
#           'dobrze': 60,
#           'wizytówką': 1,
#           'ceramiką': 1,
#           'przy': 82,
#           'nad': 208,
#           'kojarzyło': 1,
#           'wycofać': 11,
#           'icholtz': 1,
#           'emily': 5,
#           'miniaturyzacją': 1,
#           'zupełnie': 24,
#           'uda': 20,
#           'odparł': 7,
#           'barkiem': 1,
#           'statek': 2,
#           'zasobnik': 1,
#           'straciwszy': 1,
#           'nam': 60,
#           'je': 19,
#           'nią': 18,
#           'helen': 1,
#           'kupuje': 1,
#           'ponieważ': 13,
#           'znaleźć': 18,
#           'pojawi': 5,
#           'norm': 3,
#           'plecami': 9,
#           'swoim': 4,
#           'sam': 14,
#           'frań': 2,
#           'przyzwoicie': 1,
#           'no': 21,
#           'niczego': 13,
#           'bawić': 9,
#           'automatycznie': 3,
#           'ulicę': 1,
#           'golić': 4,
#           'jednak': 72,
#           'pół': 3,
#           'początkowych': 1,
#           'wydaje': 31,
#           'blado': 3,
#           'nieco': 54,
#           'trzeba': 5,
#           'zestarzeć': 1,
#           'nieśmiertelni': 1,
#           'kto': 10,
#           'woli': 1,
#           'dokonuje': 1,
#           'ujrzał': 1,
#           'otworzyła': 2,
#           'założę': 1,
#           'ucieszony': 1,
#           'bardzo': 61,
#           'ze': 183,
#           'chichocząc': 1,
#           'rozebrała': 1,
#           'płomyk': 1,
#           'nawet': 75,
#           'ostry': 1,
#           'badawczo': 4,
#           'mylić': 9,
#           'przedstawiciel': 1,
#           'miło': 1,
#           'skąd': 8,
#           'ciebie': 4,
#           'złapać': 10,
#           'felix': 2,
#           'tu': 116,
#           'pozbawione': 1,
#           'przelotnie': 4,
#           'richard': 3,
#           'przedrzeć': 1,
#           'akurat': 4,
#           'zatruta': 1,
#           'niszczyła': 1,
#           'notatnik': 1,
#           'impy': 1,
#           'boże': 1,
#           'skończyła': 4,
#           'pięć': 2,
#           'ten': 33,
#           'albo': 13,
#           'ulga': 1,
#           'dowiedział': 7,
#           'lepiej': 38,
#           'obaw': 1,
#           'liczyło': 1,
#           'kurował': 1,
#           'pojawić': 8,
#           'odpowiedzią': 1,
#           'pewne': 4,
#           'opychaniem': 1,
#           'ponownie': 20,
#           'rozmazana': 1,
#           'jestem': 5,
#           'zagrożona': 1,
#           'poczuła': 1,
#           'gdzie': 19,
#           'dzieje': 97,
#           'utrzymać': 11,
#           'przez': 181,
#           'jej': 146,
#           'przecież': 24,
#           'przekwalifikować': 1,
#           'niezbyt': 6,
#           'prawdy': 3,
#           'skinęła': 1,
#           'miała': 2,
#           'nikogo': 2,
#           'dr': 1,
#           'państwem': 1,
#           'wcisnąć': 4,
#           'lekko': 61,
#           'dziękujemy': 1,
#           'wasza': 1,
#           'czego': 15,
#           'rozbierać': 4,
#           'pisk': 1,
#           'stwierdził': 7,
#           'ręce': 3,
#           'podle': 1,
#           'technik': 3,
#           'sączyć': 1,
#           'pomyślał': 12,
#           'świat': 5,
#           'warstwa': 1,
#           'kogoś': 4,
#           'wyzbyć': 1,
#           'związać': 1,
#           'pogarszać': 1,
#           'niemieszkalna': 1,
#           'sprzedawać': 1,
#           'ekonomicznie': 1,
#           'białe': 2,
#           'zdenerwował': 1,
#           'pani': 18,
#           'pobrali': 1,
#           'dlaczego': 24,
#           'pierwszej': 2,
#           'jakieś': 12,
#           'poczęstować': 3,
#           'ogniem': 4,
#           'powiedział': 33,
#           'nauczyłem': 3,
#           'klimatu': 1,
#           'jo': 2,
#           'popularnością': 1,
#           'źle': 8,
#           'go': 66,
#           'bezszelestnie': 4,
#           'świetnie': 10,
#           'obrażona': 1,
#           'samotni': 1,
#           'jakiś': 20,
#           'znajduje': 11,
#           'koloniści': 1,
#           'powstrzymać': 20,
#           'udajesz': 2,
#           'oprzeć': 9,
#           'rozzłoszczony': 1,
#           'mnie': 20,
#           'materiałem': 1,
#           'obecnie': 6,
#           'zdarzyło': 17,
#           'wykupić': 1,
#           'roni': 1,
#           'powiedziała': 13,
#           'zatrzaskiem': 2,
#           'pewnego': 3,
#           'robi': 13,
#           'leży': 1,
#           'niedawno': 2,
#           'bóg': 1,
#           'sytuacją': 2,
#           'glukowi': 1,
#           'stąd': 53,
#           'sobie': 10,
#           'skomplikowana': 1,
#           'czarna': 4,
#           'drażliwym': 1,
#           'zestaw': 1,
#           'krótkie': 2,
#           'znajoma': 1,
#           'rozmawia': 1,
#           'gluków': 1,
#           'gluki': 1,
#           'przynajmniej': 19,
#           'spodobało': 6,
#           'waltem': 1,
#           'uważnie': 40,
#           'powtórnie': 3,
#           'dziewczynka': 3,
#           'schować': 2,
#           'chłodem': 1,
#           'bez': 56,
#           'halucynacji': 1,
#           'doznania': 1,
#           'chew': 2,
#           'młodym': 2,
#           'wypił': 1,
#           'postać': 10,
#           'maź': 1,
#           'tworząc': 2,
#           'niewyraźne': 3,
#           'żywym': 2,
#           'popiołu': 1,
#           'błękitne': 2,
#           'kiedyś': 15,
#           'uciec': 10,
#           'wyrwać': 9,
#           'iż': 22,
#           'myśląc': 2,
#           'nachylił': 1,
#           'obok': 26,
#           'przybierała': 1,
#           'gwałtownie': 21,
#           'nań': 9,
#           'wreszcie': 23,
#           'dziwnie': 17,
#           'reprodukować': 1,
#           'skończył': 7,
#           'ręka': 3,
#           'znajomy': 6,
#           'nazywasz': 10,
#           'poza': 19,
#           'zemścić': 2,
#           'cieszyć': 6,
#           'robiąca': 1,
#           'podejrzliwie': 4,
#           'cygarem': 1,
#           'uwolnić': 5,
#           'twoje': 4,
#           'oczekuję': 1,
#           'oprę': 1,
#           'mogę': 2,
#           'pakować': 2,
#           'muszę': 3,
#           'pusty': 4,
#           'zasłaniając': 1,
#           'pojawiła': 4,
#           'zmieniło': 11,
#           'opuszczać': 4,
#           'zorientować': 10,
#           'otaczałem': 1,
#           'przyłączyć': 3,
#           'dobry': 4,
#           'fizycznie': 1,
#           'chociaż': 7,
#           'pogrubiły': 1,
#           'widział': 2,
#           'przyjrzeć': 8,
#           'takim': 8,
#           'tylko': 108,
#           'też': 51,
#           'rozumiemy': 1,
#           'natychmiast': 17,
#           'żuje': 1,
#           'gdyby': 9,
#           'były': 4,
#           'wycofał': 1,
#           'obu': 1,
#           'znalazł': 9,
#           'nieznajomy': 1,
#           'zgłosiłem': 1,
#           'niech': 8,
#           'niewyraźnym': 1,
#           'zaciągnąć': 5,
#           'spakować': 2,
#           'słowami': 7,
#           'uśmiechała': 4,
#           'pogodzić': 8,
#           'zaciągnąłeś': 1,
#           'próbuję': 1,
#           'jednym': 7,
#           'składa': 8,
#           'niemożliwe': 8,
#           'żeby': 52,
#           'zawaliło': 1,
#           'widzisz': 2,
#           'sporo': 8,
#           'szefem': 1,
#           'produkuje': 2,
#           'annę': 2,
#           'uchylić': 2,
#           'wywinąć': 2,
#           'będzie': 12,
#           'uważa': 2,
#           'dwa': 12,
#           'spierać': 8,
#           'trzymał': 2,
#           'przeciw': 7,
#           'ale': 64,
#           'uśmiechem': 1,
#           'frank': 2,
#           'zapasy': 1,
#           'swojsko': 2,
#           'wzajemnie': 5,
#           'poborowi': 1,
#           'zdecydować': 8,
#           'nauczyć': 6,
#           'jutro': 5,
#           'groźnie': 4,
#           'według': 2,
#           'chcąc': 3,
#           'dziś': 14,
#           'każdemu': 4,
#           'chór': 3,
#           'jaki': 5,
#           'im': 31,
#           'jedną': 5,
#           'kontrolki': 1,
#           'wskaźnik': 1,
#           'przeniesiemy': 2,
#           'hmm': 2,
#           'jednocześnie': 7,
#           'zdarza': 15,
#           'skrępowana': 1,
#           'zamierzając': 2,
#           'panią': 1,
#           'patrząc': 5,
#           'wraca': 1,
#           'wolno': 35,
#           'wierzyć': 1,
#           'nim': 35,
#           'niezwykle': 8,
#           'założyć': 5,
#           'zebrać': 1,
#           'wrócić': 5,
#           'oddala': 4,
#           'zakochać': 2,
#           'wycofałeś': 1,
#           'takie': 13,
#           'gniewnym': 2,
#           'spokojnie': 8,
#           'zdarzało': 6,
#           'ciałem': 5,
#           'szyderczo': 2,
#           'upić': 5,
#           'ubiera': 1,
#           'okropne': 2,
#           'mądry': 1,
#           'modlić': 12,
#           'dla': 29,
#           'modlisz': 1,
#           'stamtąd': 7,
#           'grzechem': 1,
#           'postarać': 3,
#           'czytaniem': 2,
#           'słabe': 3,
#           'formalnie': 1,
#           'śmiać': 24,
#           'szczękała': 1,
#           'proszę': 7,
#           'jakby': 47,
#           'przeciwstawiać': 1,
#           'ujrzeć': 2,
#           'mężczyzna': 8,
#           'zjawić': 3,
#           'wyjaśnić': 7,
#           'prywatnej': 1,
#           'szczerze': 2,
#           'częściową': 1,
#           'przybliżał': 1,
#           'tutaj': 39,
#           'dogadać': 3,
#           'przerwał': 3,
#           'struć': 1,
#           'zmienił': 10,
#           'różnymi': 2,
#           'sprawiać': 1,
#           'stalowe': 1,
#           'skądś': 1,
#           'inni': 6,
#           'przelotnym': 1,
#           'obejrzał': 5,
#           'schein': 1,
#           'mówić': 9,
#           'maszyny': 2,
#           'mimowolnie': 2,
#           'sprzęt': 1,
#           'zostając': 1,
#           'niepowodzeniem': 1,
#           'ma': 10,
#           'znajdziemy': 1,
#           'mówiła': 2,
#           'stojącej': 1,
#           'stwierdziła': 1,
#           'nagrzany': 1,
#           'wyłącznie': 15,
#           'zacznie': 4,
#           'zdobyć': 6,
#           'błysnęły': 1,
#           'przewracać': 1,
#           'straszliwemu': 1,
#           'odkrył': 1,
#           'dojedziemy': 1,
#           'napić': 11,
#           'spieszysz': 1,
#           'poczuł': 3,
#           'pokazał': 1,
#           'ukazując': 5,
#           'mayersonowi': 1,
#           'panować': 2,
#           'rozwodzą': 1,
#           'połknąć': 1,
#           'sparzył': 1,
#           'obudziłem': 8,
#           'zaraz': 13,
#           'potrząsano': 1,
#           'zdziałać': 2,
#           'eldritch': 2,
#           'inaczej': 16,
#           'skiny': 1,
#           'jęcząc': 1,
#           'tod': 1,
#           'podnieść': 5,
#           'oglądając': 1,
#           'jakoś': 34,
#           'jowialna': 1,
#           'rozmowie': 1,
#           'dosyć': 4,
#           'wystawić': 1,
#           'wylewam': 1,
#           'mi': 3,
#           'patrz': 2,
#           'jasne': 7,
#           'później': 14,
#           'niczym': 36,
#           'reprodukująca': 1,
#           'twarz': 9,
#           'pojął': 1,
#           'temu': 30,
#           'boję': 10,
#           'swoimi': 4,
#           'katastrofą': 1,
#           'rozsmarować': 1,
#           'suche': 1,
#           'weszła': 1,
#           'nadajnik': 2,
#           'mimo': 2,
#           'znad': 4,
#           'powiesił': 1,
#           'cofnąć': 12,
#           'weń': 4,
#           'palcem': 2,
#           'popychać': 1,
#           'każdym': 3,
#           'odezwie': 1,
#           'rozeszli': 1,
#           'spokojnym': 1,
#           'współczucie': 2,
#           'wejść': 2,
#           'sześciorgiem': 1,
#           'sukcesem': 2,
#           'niebawem': 1,
#           'jego': 53,
#           'martwić': 16,
#           'takimi': 6,
#           'przeciwko': 4,
#           'oczywiste': 2,
#           'nagle': 100,
#           'zjawą': 1,
#           'wiele': 10,
#           'odparło': 1,
#           'cząsteczkami': 1,
#           'da': 17,
#           'zjawami': 1,
#           'czymś': 16,
#           'słabo': 9,
#           'przedmiotem': 2,
#           'tunel': 1,
#           'sprzedają': 1,
#           'taka': 10,
#           'niecierpliwią': 1,
#           'czas': 6,
#           'planetą': 1,
#           'uważasz': 4,
#           'stać': 19,
#           'zapach': 10,
#           'siedząca': 1,
#           'udało': 17,
#           'j': 3,
#           'zoe': 1,
#           'przenosił': 1,
#           'grodzi': 1,
#           'nieśmiertelny': 2,
#           'dotknięty': 1,
#           'zdarzy': 8,
#           'umartwiać': 1,
#           'wydarzy': 11,
#           'palmerem': 1,
#           'częściowo': 2,
#           'oddzielić': 1,
#           'radzić': 1,
#           'przydało': 2,
#           'zaistnieć': 1,
#           'samotność': 1,
#           'zmarszczył': 2,
#           'was': 2,
#           'górował': 1,
#           'nora': 1,
#           'identyfikuję': 1,
#           'stykaliśmy': 1,
#           'zetknęliśmy': 2,
#           'mylisz': 6,
#           'oblizując': 1,
#           'wątpliwości': 1,
#           'podział': 8,
#           'ucałowała': 1,
#           'wydajesz': 1,
#           'oczyścić': 2,
#           'zobaczymy': 1,
#           'budzą': 1,
#           'oglądaniem': 1,
#           'spać': 8,
#           'przyjacielu': 1,
#           'wzbogacić': 2,
#           'całkiem': 27,
#           'zachowuje': 2,
#           'utrwali': 1,
#           'przydać': 6,
#           'palmera': 1,
#           'niewątpliwie': 3,
#           'słowem': 2,
#           'ludziom': 4,
#           'rozprzestrzenia': 1,
#           'posunął': 1,
#           'instynktownie': 3,
#           'wydawać': 10,
#           'ach': 3,
#           'obudzę': 2,
#           'topi': 1,
#           'nachyliła': 1,
#           'oszukany': 3,
#           'rozczarowany': 1,
#           'spodziewałem': 7,
#           'podeprzeć': 1,
#           'skarcony': 1,
#           'obawiasz': 2,
#           'bubber': 1,
#           'bliżej': 13,
#           'geografię': 1,
#           'policzki': 1,
#           'listonosz': 1,
#           'dziać': 5,
#           'zmieniać': 4,
#           'podziewał': 2,
#           'ruszył': 5,
#           'dookoła': 27,
#           'zestarzeje': 2,
#           'coraz': 65,
#           'aż': 31,
#           'dokładnie': 15,
#           'wiedząc': 2,
#           'spoglądając': 2,
#           'uśmiech': 5,
#           'spotkamy': 2,
#           'naprzód': 14,
#           'chmurami': 1,
#           'przykrego': 1,
#           'latarni': 1,
#           'podziewa': 2,
#           'cichy': 10,
#           'liczyć': 4,
#           'u': 37,
#           'wideofony': 1,
#           'którym': 1,
#           'orientuję': 1,
#           'zaczynał': 1,
#           'święto': 1,
#           'ruch': 2,
#           'zachowywała': 1,
#           'życzę': 2,
#           'para': 4,
#           'kazaliby': 1,
#           'zwrócić': 4,
#           'zrozumiałe': 2,
#           'kończy': 12,
#           'ciężarówka': 1,
#           'ubranie': 1,
#           'wyraz': 11,
#           'miewa': 2,
#           'wzmocniony': 1,
#           'uśmiechał': 8,
#           'kłaniało': 1,
#           'wkoło': 2,
#           'właśnie': 42,
#           'znanemu': 1,
#           'niepewności': 1,
#           'skontaktujesz': 1,
#           'ta': 16,
#           'instytucja': 1,
#           'herbert': 2,
#           'przyszedł': 1,
#           'hałaśliwie': 2,
#           'pewnie': 15,
#           'naprzeciwko': 1,
#           'niejako': 4,
#           'nazywał': 5,
#           'opłaca': 2,
#           'pojawiać': 7,
#           'przypuszczam': 5,
#           'jedynie': 15,
#           'masz': 10,
#           'ile': 8,
#           'rozłazi': 1,
#           'ciągle': 5,
#           'zatrzymać': 8,
#           'byłaś': 1,
#           'integrujemy': 1,
#           'urodzić': 2,
#           'głupio': 3,
#           'wydarzyło': 15,
#           's': 3,
#           'blisko': 6,
#           'oni': 10,
#           'stoso': 2,
#           'orientujemy': 2,
#           'cisza': 3,
#           'oddaliła': 2,
#           'jory': 5,
#           'wyłączyć': 1,
#           'kurz': 3,
#           'odzywa': 1,
#           'zdyszany': 2,
#           'wydarzyć': 3,
#           'wyraźnie': 15,
#           'zerkając': 1,
#           'znajdować': 11,
#           'wstrętnie': 1,
#           'właściwie': 15,
#           'lory': 1,
#           'on': 27,
#           'więc': 36,
#           'tyle': 3,
#           'przerwać': 1,
#           'zazwyczaj': 4,
#           'jednostka': 1,
#           'kontrolą': 2,
#           'zwabić': 1,
#           'ubrać': 1,
#           'półfuntowa': 1,
#           'przeszukał': 1,
#           'pukanie': 6,
#           'chyba': 39,
#           'brzęk': 2,
#           'przebiegle': 2,
#           'joemu': 10,
#           'zaduch': 1,
#           'pat': 9,
#           'g': 1,
#           'strzeże': 1,
#           'joe': 57,
#           'twarda': 1,
#           'wieczny': 1,
#           'przejść': 4,
#           'przykrość': 1,
#           'zmieszanie': 1,
#           'jaśniejsza': 1,
#           'tą': 15,
#           'promieniować': 5,
#           'swymi': 5,
#           'gdzieś': 28,
#           'stłukła': 2,
#           'zmusić': 5,
#           'premia': 1,
#           'ustalić': 3,
#           'stopniowo': 1,
#           'zamykały': 2,
#           'winny': 2,
#           'nic': 17,
#           'poszperała': 1,
#           'arkuszowi': 1,
#           'czerwieni': 6,
#           'bezskutecznie': 2,
#           'obojętnie': 5,
#           'żadne': 4,
#           'ono': 9,
#           'ponieść': 2,
#           'równocześnie': 7,
#           'nasze': 3,
#           'przeciętnie': 1,
#           'podoba': 20,
#           'sir': 3,
#           'marszczy': 1,
#           'promiennie': 7,
#           'porozumieć': 3,
#           'tęga': 1,
#           'niestosowny': 1,
#           'kiwnęła': 1,
#           'porozmawiam': 2,
#           'odbywać': 3,
#           'zinfiltrować': 1,
#           'uruchomić': 2,
#           'telepaci': 1,
#           'ilu': 2,
#           'posłużyć': 2,
#           'ci': 5,
#           'dokąd': 1,
#           'wypadki': 2,
#           'stanton': 1,
#           'nominalnie': 1,
#           'sądzić': 1,
#           'kolonizacja': 1,
#           'przeprowadzić': 2,
#           'mrówki': 1,
#           'znajdują': 1,
#           'mgliste': 2,
#           'runciter': 7,
#           'wśród': 27,
#           'chwilę': 23,
#           'równie': 8,
#           'niepewnie': 27,
#           'skontaktować': 2,
#           'dni': 1,
#           'bezradni': 1,
#           'przeze': 1,
#           'chcę': 3,
#           'odsłaniając': 3,
#           'surowymi': 1,
#           'roztargniony': 1,
#           'człowiekowi': 6,
#           'tłumaczyłem': 1,
#           'zbiera': 2,
#           'wybiera': 1,
#           'energicznie': 1,
#           'jeden': 19,
#           'swym': 7,
#           'al': 4,
#           'mówił': 1,
#           'poznać': 4,
#           'trzy': 15,
#           'dziwne': 9,
#           'triumfalny': 1,
#           'spod': 29,
#           'pamięć': 4,
#           'chciałbym': 2,
#           'zachować': 14,
#           'przystojna': 1,
#           'znużony': 2,
#           'pewnym': 2,
#           'wendy': 4,
#           'tłustemu': 1,
#           'ubiegłej': 1,
#           'zdaje': 21,
#           'ogrom': 1,
#           'naszym': 2,
#           'automatycznej': 1,
#           'popieścić': 1,
#           'większe': 1,
#           'fred': 2,
#           'rozpakować': 1,
#           'duża': 3,
#           'tacy': 4,
#           'jako': 35,
#           'śniło': 4,
#           'zmęczony': 6,
#           'jon': 3,
#           'utrwalić': 1,
#           'ściskać': 1,
#           'eksterminatorzy': 1,
#           'dokonaniu': 1,
#           'razem': 20,
#           'rozpacz': 1,
#           'faktem': 2,
#           'bezładnie': 1,
#           'tito': 3,
#           'znaleźli': 5,
#           'dość': 13,
#           'wystarczająco': 5,
#           'zamykając': 1,
#           'badał': 1,
#           'wystartować': 2,
#           'winda': 1,
#           'umotywować': 1,
#           'ona': 20,
#           'trzęsła': 5,
#           'najgorsze': 2,
#           'odgłos': 3,
#           'podnosząc': 2,
#           'odwrócić': 8,
#           'czyżby': 1,
#           'nami': 3,
#           'wejdź': 2,
#           'niskiemu': 1,
#           'wcale': 14,
#           'możliwość': 1,
#           'trudno': 4,
#           'przekonać': 21,
#           'konieczne': 1,
#           'stara': 7,
#           'wydostać': 7,
#           'mieszane': 1,
#           'ekstrawertyczką': 1,
#           'blada': 1,
#           'wypadek': 4,
#           'runciterowi': 1,
#           'zwykłe': 1,
#           'nowa': 3,
#           'tuż': 16,
#           'ośrodek': 1,
#           'filiżanka': 1,
#           'kartą': 1,
#           'wartości': 1,
#           'porowata': 1,
#           'nade': 10,
#           'moratorium': 1,
#           'von': 3,
#           'zapanować': 3,
#           'płakać': 3,
#           'łatwiej': 1,
#           'ryby': 1,
#           'zajmowali': 2,
#           'zęby': 2,
#           'siedząc': 3,
#           'korytarzem': 2,
#           'niezgrabnie': 3,
#           'dwudziestopieciocentówce': 1,
#           'uprzejmy': 1,
#           'powiedzieć': 11,
#           'właściciel': 3,
#           'zauważalnej': 1,
#           'namówić': 3,
#           'wideofonem': 1,
#           'aktualnie': 1,
#           'dies': 1,
#           'monetom': 1,
#           'konkretny': 1,
#           'światło': 16,
#           'pierwszy': 13,
#           'monotonnie': 1,
#           'mogło': 3,
#           'higienicznym': 1,
#           'bezpłatną': 1,
#           'wody': 4,
#           'dźwięk': 9,
#           'wiadomość': 1,
#           'arkusz': 1,
#           'wcześniej': 6,
#           'elektro': 1,
#           'spodziewać': 15,
#           'dodzwonić': 3,
#           'dostać': 5,
#           'tyra': 1,
#           'panem': 5,
#           'spotkać': 8,
#           'niepokój': 1,
#           'głównie': 10,
#           'strzępków': 1,
#           'przewrócił': 5,
#           'drobnej': 1,
#           'przyszła': 1,
#           'opanować': 11,
#           'upewnić': 11,
#           'zatrzymał': 7,
#           'pięćdziesięciogentówce': 1,
#           'pięćdziesięciocen': 1,
#           'sześć': 3,
#           'nimi': 23,
#           'runcitera': 2,
#           'portret': 1,
#           'spo': 1,
#           'gabinet': 1,
#           'wchodzącym': 1,
#           'dojść': 1,
#           'próbowaliśmy': 1,
#           ...}),
#  'się, z': Counter({'niezwykle': 1,
#           '#sum': 1414,
#           'łóżka': 5,
#           'jego': 17,
#           'pościeli': 1,
#           'łazienki': 1,
#           'psychiatrą': 1,
#           'nim': 81,
#           'tym': 49,
#           'żoną': 2,
#           'blauem': 1,
#           'czasem': 5,
#           'panną': 1,
#           'urazy': 1,
#           'ulgą': 1,
#           'panem': 17,
#           'miejsca': 27,
#           'palmerem': 3,
#           'wami': 9,
#           'towarzyszami': 1,
#           'nimi': 30,
#           'koparką': 1,
#           'dokładnością': 1,
#           'niesmakiem': 6,
#           'frań': 1,
#           'mojego': 1,
#           'wolą': 1,
#           'todem': 1,
#           'kącików': 1,
#           'ziemią': 1,
#           'eldritchem': 1,
#           'szoku': 1,
#           'umowy': 1,
#           'tobą': 28,
#           'nazwą': 1,
#           'felixem': 1,
#           'długimi': 1,
#           'roni': 2,
#           'głośnym': 4,
#           'tego': 26,
#           'mayersonem': 1,
#           'innymi': 8,
#           'interesów': 1,
#           'odrazą': 1,
#           'nami': 19,
#           'szefem': 1,
#           'krzesła': 5,
#           'przeniesienia': 1,
#           'nią': 28,
#           'sytuacją': 3,
#           'annę': 1,
#           'głośnika': 1,
#           'trzaskiem': 8,
#           'powrotem': 31,
#           'dala': 6,
#           'kanapy': 1,
#           'takim': 2,
#           'zadowoleniem': 3,
#           'psychoanalitykiem': 1,
#           'fiolki': 1,
#           'nikim': 5,
#           'hnattem': 1,
#           'zażyciem': 1,
#           'szacunkiem': 3,
#           'fotela': 7,
#           'rzeczywistym': 1,
#           'marsa': 1,
#           'grymasem': 1,
#           'uchwytu': 1,
#           'garstką': 1,
#           'wrażenia': 3,
#           'jednym': 2,
#           'nie': 2,
#           'niechęcią': 1,
#           'entuzjazmem': 1,
#           'najbliższą': 1,
#           'czym': 1,
#           'faktem': 2,
#           'namysłem': 9,
#           'pola': 1,
#           'gabinetu': 1,
#           'otworu': 1,
#           'zarostem': 1,
#           'podniecenia': 1,
#           'pod': 1,
#           'twee': 1,
#           'kimś': 11,
#           'jej': 5,
#           'hotelem': 1,
#           'wielkiego': 1,
#           'moratorium': 1,
#           'uwagą': 7,
#           'kolejki': 1,
#           'dwu': 2,
#           'treścią': 2,
#           'moimi': 7,
#           'bóg': 1,
#           'czego': 2,
#           'bliska': 2,
#           'puszki': 1,
#           'zakurzonej': 1,
#           'samochodem': 1,
#           'edie': 1,
#           'ciemności': 2,
#           'każdą': 5,
#           'rayem': 1,
#           'przeszłości': 1,
#           'palców': 5,
#           'wyraźnym': 1,
#           'biu': 1,
#           'postaci': 1,
#           'ciekawością': 1,
#           'niej': 16,
#           'godnością': 3,
#           'jednego': 3,
#           'powodu': 2,
#           'wkurzonym': 1,
#           'encyklopedią': 1,
# ...
#           'świeca': 1,
#           'mnie': 1,
#           'siostra': 1,
#           'sen': 1,
#           'jednej': 1,
#           'chichoty': 1,
#           'pozostałe': 1,
#           'istotą': 1,
#           'rozbójnicy': 1,
#           'ukatrupienie': 1,
#           'przypuszczałem': 1,
#           'dogorywać': 1,
#           'poprzednio': 3,
#           'jedwabie': 1,
#           'wilka': 1,
#           'wnet': 1,
#           'trwała': 1,
#           'wymagała': 1,
#           'jechać': 1,
#           'niż': 1,
#           'was': 1,
#           'róże': 1,
#           'koń': 1,
#           'ciemier': 1,
#           'powietrze': 1,
#           'jakiemukolwiek': 1,
#           'słowa': 1,
#           'wyciągnęlibyśmy': 1,
#           'gwendeling': 1,
#           'pierwsze': 1,
#           'lżyć': 1,
#           'inni': 2,
#           'sądziła': 1,
#           'miałaby': 1,
#           'sześciu': 1,
#           'większy': 1,
#           'jakąkolwiek': 1,
#           'łzy': 1,
#           'osiemset': 1,
#           'dnia': 1,
#           'tłumaczyć': 1,
#           'teraz': 1,
#           'przewidziany': 1,
#           'kierować': 1,
#           'pokonanie': 1,
#           'nawigację': 1,
#           'gdziekolwiek': 2,
#           'waży': 1,
#           'istotę': 1,
#           'nasza': 2,
#           'właściwą': 1,
#           'autorzy': 1,
#           'kiedykol': 1,
#           'frapującą': 1,
#           'ważyli': 1,
#           'dotąd': 2,
#           'ich': 1,
#           'łóżkowe': 1,
#           'śródziemnomorska': 1,
#           'jeśli': 2,
#           'rozum': 2,
#           'składni': 1,
#           'najszybsze': 1,
#           'najlepsze': 1,
#           'wiedzieli': 1,
#           'podsumowaniem': 1,
#           'piwne': 1,
#           'tuzin': 1,
#           'sądzisz': 1,
#           'corcoran': 1,
#           'dyplomatów': 1,
#           'gdyby': 1,
#           'spartańskich': 1,
#           'morderczo': 1,
#           'pełna': 1,
#           'mechanika': 1,
#           'dostrzegamy': 1,
#           'wpuścić': 1,
#           'wprzódy': 1,
#           'tobie': 1,
#           'te': 1,
#           'słyszałem': 1,
#           'miriady': 1,
#           'przyczynkarstwem': 1,
#           'może': 1,
#           'marsjański': 1}),
#  'niż, para': Counter({'różowych': 1, '#sum': 1}),
#  'para': Counter({'różowych': 3,
#           '#sum': 46,
#           'przycisnął': 1,
#           'potem': 1,
#           'i': 1,
#           'lodowato': 1,
#           'wielkich': 1,
#           'kuropatw': 1,
#           'spodni': 1,
#           'miechów': 1,
#           'sam': 1,
#           'siedmiomilowych': 1,
#           'stóp': 1,
#           'krystalicznych': 1,
#           'zamglonych': 1,
#           'lśniących': 2,
#           'unosiła': 1,
#           'oddechu': 1,
#           'którą': 1,
#           'przeciwsłonecznych': 1,
#           'robotów': 1,
#           'strażników': 1,
#           'kół': 1,
#           'białych': 1,
#           'tancerzy': 1,
#           'starszych': 1,
#           'jego': 1,
#           'pomieszczenie': 1,
#           'jak': 1,
#           'miała': 1,
#           'tommy': 1,
#           'nie': 1,
#           'skórzanych': 1,
#           'jakby': 1,
#           'wodna': 2,
#           'milcz': 1,
#           'grafów': 1,
#           '20': 1,
#           'czy': 2,
#           'buchająca': 1,
#           'oczu': 1,
#           'ścinająca': 1}),
#  'para, różowych': Counter({'groszków': 1,
#           '#sum': 3,
#           'pereł': 1,
#           'kajaków': 1}),
#  'różowych': Counter({'groszków': 1,
#           '#sum': 9,
#           'pereł': 1,
#           'kajaków': 1,
#           'ludzi': 1,
#           'nóżek': 1,
#           'miętówek': 2,
#           'kapciach': 1,
#           'kart': 1}),
#  'różowych, groszków': Counter({'a': 1, '#sum': 1}),
#  'groszków': Counter({'a': 1, '#sum': 1}),
#  'groszków, a': Counter({'raczej': 1, '#sum': 1}),
#  'a, raczej': Counter({'para': 1,
#           '#sum': 81,
#           'zyskał': 1,
#           'próbowała': 1,
#           'nie': 1,
#           'coś': 1,
#           'żył': 1,
#           'pan': 1,
#           'tak': 2,
#           'powiedział': 1,
#           'będzie': 1,
#           't': 1,
#           'otrzymywaliśmy': 2,
#           'byli': 1,
#           'przemożną': 1,
#           'to': 2,
#           'jego': 3,
#           'poprawił': 1,
#           'z': 1,
#           'jeden': 1,
#           'zapadnięte': 1,
#           'komputer': 1,
#           'wiążącej': 1,
#           'pomyślał': 1,
#           'było': 1,
#           'jako': 1,
#           'unoszących': 1,
#           'szczerze': 1,
#           'zniknął': 1,
#           'uciekam': 1,
#           'zad': 1,
#           'wtedy': 1,
#           'śmierć': 1,
#           'pociągnąłem': 1,
#           'panie': 1,
#           'wszystkich': 1,
#           'odskoczył': 1,
#           'pracę': 1,
#           'życia': 1,
#           'skomplikowaną': 1,
#           'na': 1,
#           'już': 2,
#           'dwa': 1,
#           'zniknęła': 1,
#           'margaryną': 1,
#           'zakrztusił': 1,
#           'wielu': 1,
#           'płaczliwie': 1,
#           'w': 1,
#           'nad': 1,
#           'widmo': 1,
#           'jej': 2,
#           'skacząc': 1,
#           'pieśń': 1,
#           'tuż': 1,
#           'pochowały': 1,
#           'naprawdę': 1,
#           'niedobrym': 1,
#           'przejąć': 1,
#           'informację': 1,
#           'do': 1,
#           'fałszywie': 1,
#           'rozumności': 1,
#           'nieprawdę': 1,
#           'dopóki': 1,
#           'in': 1,
#           'fotel': 1,
#           'śliskie': 1,
#           'białe': 1,
#           'we': 1,
#           'nic': 1,
#           'wzajemne': 1,
#           'wdowy': 1,
#           'nasi': 1,
#           'prognózki': 1}),
#  'raczej': Counter({'para': 1,
#           '#sum': 464,
#           'trent': 1,
#           'chcę': 1,
#           'orzechogłowi': 1,
#           'zyskał': 1,
#           'próbowała': 1,
#           'przedwcześnie': 1,
#           'nie': 34,
#           'coś': 1,
#           'żył': 1,
#           'pan': 1,
#           'tak': 3,
#           'powiedział': 1,
#           'będzie': 1,
#           't': 1,
#           'otrzymywaliśmy': 2,
#           'warknął': 1,
#           'kiedy': 1,
#           'nam': 1,
#           'byli': 1,
#           'w': 7,
#           'przemożną': 1,
#           'to': 6,
#           'poczynania': 1,
#           'jego': 4,
#           'poprawił': 1,
#           'namiastkę': 1,
#           'z': 10,
#           'wydrukowałem': 1,
#           'jeden': 1,
#           'uśpiona': 1,
#           'krawędź': 1,
#           'zapadnięte': 1,
#           'komputer': 1,
#           'wiel': 1,
#           'ze': 1,
#           'stawiając': 1,
#           'troski': 1,
#           'wiążącej': 1,
#           'pomyślał': 1,
#           'pełen': 1,
#           'wygodne': 1,
#           'niewiele': 2,
#           'znikoma': 1,
#           'znikomą': 1,
#           'stwierdził': 2,
#           'dzielili': 1,
#           'niewielu': 1,
#           'usiłował': 1,
#           'drobne': 1,
#           'sposób': 1,
#           'kuliło': 1,
#           'o': 7,
#           'szeleszczący': 1,
#           'ryk': 1,
#           'powiedzieć': 1,
#           'że': 5,
#           'smocze': 1,
#           'zły': 1,
#           'napisy': 1,
#           'prawie': 1,
#           'usmażenie': 1,
#           'dziury': 1,
#           'paskudnym': 1,
#           'walijską': 1,
#           'było': 1,
#           'należało': 1,
#           'jako': 2,
#           'pisk': 1,
#           'kształtem': 1,
#           'spokojnie': 1,
#           'mroczny': 1,
#           'zadowolony': 1,
#           'jakiś': 1,
#           'unoszących': 1,
#           'szczerze': 1,
#           'odwrotnie': 1,
#           'je': 2,
#           'papierowy': 1,
#           'żałośnie': 1,
#           'niski': 2,
#           'hm': 1,
#           'do': 4,
#           'niepraktyczną': 1,
#           'czekoladki': 1,
#           'przyjaźnie': 1,
#           'ekologię': 1,
#           'go': 2,
#           'dwa': 2,
#           'ciepło': 1,
#           'kopce': 1,
#           'płynie': 1,
#           'praktyki': 1,
#           'typem': 1,
#           'jak': 3,
#           'ząb': 1,
#           'nieprzyjemny': 1,
#           'pewnie': 1,
#           'niemożliwe': 1,
#           'umrzeć': 1,
#           'krótka': 1,
#           'zniknął': 1,
#           'wolą': 1,
#           'uciekam': 1,
#           'czosnek': 1,
#           'całą': 1,
#           'drwiący': 1,
#           'zad': 1,
#           'setki': 1,
#           'wtedy': 1,
#           'próbując': 1,
#           'przestać': 1,
#           'śmierć': 1,
#           'stwarza': 1,
#           'pociągnąłem': 1,
#           'panie': 1,
#           'niepodobny': 1,
#           'dziwne': 1,
#           'wszystkich': 1,
#           'ostateczna': 1,
#           'miałem': 1,
#           'odskoczył': 1,
#           'pracę': 1,
#           'życia': 1,
#           'uznać': 2,
#           'gwałtownie': 1,
#           'skomplikowaną': 1,
#           'na': 9,
#           'już': 2,
#           'nad': 4,
#           'nieortodoksyjny': 1,
#           'zniknęła': 1,
#           'wycie': 1,
#           'znany': 1,
#           'podpalaczy': 1,
#           'się': 2,
#           'sunie': 1,
#           'utopić': 1,
#           'margaryną': 1,
#           'zmęczony': 1,
#           'niż': 4,
#           'przerażający': 1,
#           'krok': 1,
#           'złowrogie': 1,
#           'ochotę': 1,
#           'rozbawiony': 1,
#           'święty': 1,
#           'obciążą': 1,
#           'przestań': 1,
#           'cmwm': 1,
#           'młody': 1,
#           'litość': 1,
#           'niedbałą': 1,
#           'niezwykły': 1,
#           'przekleństwo': 1,
#           'zakrztusił': 1,
#           'hipnotyczną': 1,
#           'wielu': 1,
#           'komicznego': 1,
#           'nieprzyjemne': 1,
#           'słabiutko': 1,
#           'płaczliwie': 1,
#           'galeria': 1,
#           'rzadko': 2,
#           'uspokajające': 1,
#           'okrągłą': 1,
#           'chyba': 1,
#           'dobijają': 1,
#           'trudno': 2,
#           'być': 1,
#           'przyjąć': 1,
#           'legendą': 1,
#           'złowieszcza': 1,
#           'owadów': 1,
#           'dziewczęcy': 1,
#           'rozległy': 1,
#           'wiśniowe': 1,
#           'księżniczka': 1,
#           'my': 1,
#           'widmo': 1,
#           'płynęła': 1,
#           'jęk': 1,
#           'obojętny': 1,
#           'dziewczynka': 1,
#           'szarawe': 1,
#           'jej': 3,
#           'powinniście': 1,
#           'tinuviel': 1,
#           'wynagrodzić': 1,
#           'imion': 1,
#           'stale': 1,
#           'skacząc': 1,
#           'osobliwego': 1,
#           'niezwykła': 1,
#           'bardzo': 1,
#           'przeszył': 1,
#           'nomenklaturą': 1,
#           'pieśń': 1,
#           'monotonne': 1,
#           'niewesołym': 1,
#           'zaczekać': 1,
#           'niewygodnie': 1,
#           'kiepsko': 2,
#           'by': 2,
#           'tuż': 1,
#           'ja': 2,
#           'bilans': 1,
#           'liberał': 1,
#           'kwaśno': 1,
#           'czworonoga': 1,
#           'rzadkie': 1,
#           'za': 2,
#           'poczułem': 1,
#           'pochowały': 1,
#           'bezmyślnie': 1,
#           'dziwny': 1,
#           'palnął': 1,
#           'naprawdę': 1,
#           'jeremiasz': 1,
#           'komórka': 1,
#           'opuścić': 1,
#           'aniżeli': 5,
#           'pesymistycznie': 1,
#           'niedobrym': 1,
#           'cicho': 1,
#           'topologicznej': 1,
#           'przejąć': 1,
#           'postrzegania': 1,
#           'przykrym': 1,
#           'nazw': 2,
#           'podkopy': 1,
#           'bitokratyczne': 1,
#           'infiltracja': 1,
#           'wszystko': 1,
#           'wciąż': 1,
#           'ku': 1,
#           'jest': 2,
#           'znaczeń': 1,
#           'oprzyrządowanie': 1,
#           'francuski': 1,
#           'paradoksalny': 1,
#           'kiepska': 1,
#           'uświadomić': 1,
#           'kłopotliwych': 1,
#           'początek': 1,
#           'polityczne': 1,
#           'informację': 1,
#           'zagadkowe': 1,
#           'umiarkowany': 1,
#           'fałszywie': 1,
#           'rozumności': 1,
#           'dziwacznym': 1,
#           'rozumne': 1,
#           'nieprywatnych': 1,
#           'od': 2,
#           'pewna': 1,
#           'zespołu': 1,
#           'ową': 1,
#           'chłodny': 1,
#           'przemieszcza': 1,
#           'mieszczańskiej': 1,
#           'nieprawdę': 1,
#           'tępawa': 1,
#           'marzenie': 1,
#           'unerwieniem': 1,
#           'sądu': 1,
#           'szybko': 1,
#           'różne': 1,
#           'informacja': 1,
#           'mało': 1,
#           'zmorą': 1,
#           'pesymistycznym': 1,
#           'którym': 1,
#           'przez': 1,
#           'u': 1,
#           'wariat': 1,
#           'dopóki': 1,
#           'orzechowe': 1,
#           'ponurego': 1,
#           'przezroczystego': 1,
#           'dalszych': 1,
#           'znaczna': 1,
#           'wprost': 1,
#           'nieprzyjaznym': 1,
#           'in': 1,
#           'ich': 1,
#           'trywialne': 1,
#           'wychowywać': 1,
#           'mi': 1,
#           'podławy': 1,
#           'tego': 1,
#           'falowało': 1,
#           'fotel': 1,
#           'pieszczotliwie': 1,
#           'monstrualne': 1,
#           'okładziny': 1,
#           'niedostrzegalna': 1,
#           'czymś': 1,
#           'słono': 1,
#           'skojarzenie': 1,
#           'optymista': 1,
#           'wisiałem': 1,
#           'swoją': 1,
#           'źle': 1,
#           'nic': 2,
#           'śliskie': 1,
#           'co': 1,
#           'jedną': 1,
#           'neutrina': 1,
#           'lichy': 1,
#           'przed': 1,
#           'rzeźnia': 1,
#           'kwestia': 1,
#           'białe': 1,
#           'wartość': 1,
#           'gałęzi': 1,
#           'misji': 1,
#           'jakbym': 1,
#           'we': 1,
#           'białawego': 1,
#           'oznaką': 1,
#           'anachoretą': 1,
#           'uprzytomnić': 1,
#           'projektowaną': 1,
#           'chaotycznie': 1,
#           'godnej': 1,
#           'ma': 1,
#           'poskładanymi': 1,
#           'wzajemne': 1,
#           'optymistyczne': 1,
#           'kłopotliwa': 1,
#           'obłe': 1,
#           'nazwać': 1,
#           'pojazdy': 1,
#           'wdowy': 1,
#           'zacnym': 1,
#           'znakomitego': 1,
#           'naturalistą': 1,
#           'drogo': 1,
#           'sławią': 1,
#           'pozaświadomie': 1,
#           'przeszkodę': 1,
#           'zespoły': 1,
#           'przemilczany': 1,
#           'typowe': 1,
#           'ośmielę': 1,
#           'promieniowało': 1,
#           'tamy': 1,
#           'nasi': 1,
#           'prognózki': 1}),
#  'raczej, para': Counter({'różowych': 1, '#sum': 1}),
#  'różowych, pereł': Counter({'poprawił': 1, '#sum': 1}),
#  'pereł': Counter({'poprawił': 1, '#sum': 3, 'i': 1, 'narkotycznego': 1}),
#  'pereł, poprawił': Counter({'się': 1, '#sum': 1}),
#  'poprawił': Counter({'się': 15,
#           '#sum': 70,
#           'go': 18,
#           'barney': 1,
#           'ją': 5,
#           'joe': 4,
#           'spokojnie': 1,
#           'na': 2,
#           'zbroję': 1,
#           'nobby': 1,
#           'półpancerz': 1,
#           'inny': 1,
#           'wojna': 1,
#           'jaspis': 1,
#           'dwukwiat': 1,
#           'odruchowo': 2,
#           'mort': 1,
#           'okulary': 1,
#           'mag': 1,
#           'gniewie': 1,
#           'infekcja': 1,
#           'broń': 1,
#           'johnny': 1,
#           'andy': 1,
#           'pludry': 1,
#           'takim': 1,
#           'rycerz': 1,
#           'kanclerz': 1,
#           'kopniakiem': 1,
#           'mnie': 1,
#           'odcinając': 1}),
#  'poprawił, się': Counter({'w': 2,
#           '#sum': 15,
#           'leo': 1,
#           'niech': 1,
#           'bo': 1,
#           'joe': 1,
#           'byliście': 1,
#           'na': 2,
#           'szybko': 3,
#           'odruchowo': 1,
#           'demon': 1,
#           'znowu': 1}),
#  'w, myślach': Counter({'chciałam': 1,
#           '#sum': 40,
#           'jakiś': 1,
#           'zobaczył': 1,
#           'to': 1,
#           'do': 1,
#           'ten': 2,
#           'winda': 1,
#           'starając': 1,
#           'ujrzał': 1,
#           'jeszcze': 1,
#           'freya': 1,
#           'o': 1,
#           'pokój': 1,
#           'muszę': 1,
#           'zapytał': 1,
#           'vimes': 1,
#           'brzmienie': 1,
#           'tam': 1,
#           'wezbrało': 1,
#           'znowu': 1,
#           'ale': 2,
#           'wpływać': 1,
#           'co': 1,
#           'chcesz': 1,
#           'nieoczekiwanie': 1,
#           'wszystko': 1,
#           'nadal': 1,
#           'wyzywałem': 1,
#           'nie': 2,
#           'jason': 1,
#           'w': 1,
#           'czy': 1,
#           'jesteście': 1,
#           'że': 1,
#           'i': 2,
#           'kiedy': 1}),
#  ...}

# %%
def backoff(chains, author, ngram):
    try:
        x = ', '.join(ngram[:-1])
        p = author_chains[author][x][ngram[-1]]\
                / author_chains['global'][x]["#sum"]
        return p
    except KeyError:
        try:
            backoff_weight = backoff_weight_chain(chains, author, ngram[-2], x)
            return backoff_weight*backoff(chains, author, ngram[:-1])
        except (IndexError, ZeroDivisionError):
            return 0
        
def backoff_weight_chain(chains, author, w_p1, w_p_all):
    top, bottom = 1, 1
    try:
        top = 1 - (chains[author][w_p_all]['#sum']/chains['global'][w_p_all]['#sum'])
    except KeyError:
        pass
    try:
        bottom = 1 - (chains[author][w_p1]['#sum']/chains['global'][w_p1]['#sum'])
    except KeyError:
        pass 
    return top/bottom

# %%
hit = 0
total = 0
tp, fp, tn, fn = 0, 0, 0, 0
total_authors = len(author_chains) -1 
for author_org, book in test_set:
    author_metrics = {author: 0 for author in author_chains}
    words = re.findall(r'\w+', open(os.path.join(test_dir, book), 'r').read().lower())[:1000] # sample
    for i in range(len(words)-order):
        ngram = words[i:i+order]
        for author in author_chains:
            p = backoff(author_chains, author, ngram)
            author_metrics[author]  += p
    max_author_val, max_author = 0, None
    for author in author_metrics:
        if author == 'global':
            continue
        if author_metrics[author] >= max_author_val:
            max_author_val, max_author = author_metrics[author], author
    if max_author == author_org:
        tp += 1
        tn += (total_authors -1)
        hit += 1
    else:
        tn += (total_authors - 2)
        fp += 1 
        fn += 1 
    total += 1
    print(f'Book {book} by {author_org}: {max_author} with {np.around(max_author_val, decimals=2)}')
print(f"Accuracy: {hit/total}, {hit}/{total}")
print(f"Recall {tp/(tp + fp)}, precision {tp/(tp+fn)}")
# Out:
# Book Philip_K_Dick_-_Kosmiczne_marionetki.txt by Philip_K_Dick_: Stephen_King_ with 11.22
# Book Terry_Pratchett_-_Czarodzicielstwo.txt by Terry_Pratchett_: Terry_Pratchett_ with 16.7
# Book Terry_Pratchett_-_Kosiarz.txt by Terry_Pratchett_: Terry_Pratchett_ with 19.0
# Book Terry_Pratchett_-_Piramidy.txt by Terry_Pratchett_: Terry_Pratchett_ with 15.51
# Book Stephen_King_-_Marzenia_i_Koszmary_2.txt by Stephen_King_: Stephen_King_ with 13.79
# Book Sapkowski_Andrzej_-_Okruch_lodu.txt by Sapkowski_Andrzej_: Sapkowski_Andrzej_ with 4.99
# Book Tolkien_J_R_R_-_O_Tuorze_i_jego_przybyciu_do_Gondolinu.txt by Tolkien_J_R_R_: Tolkien_J_R_R_ with 7.86
# Book Lem_Stanislaw_-_Summa_Technologiae.txt by Lem_Stanislaw_: Lem_Stanislaw_ with 8.51
# Book Lem_Stanislaw_-_Bajki_robotow.txt by Lem_Stanislaw_: Lem_Stanislaw_ with 4.42
# Book Lem_Stanislaw_-_Niezwyciezony.txt by Lem_Stanislaw_: Lem_Stanislaw_ with 9.09
# Accuracy: 0.9, 9/10
# Recall 0.9, precision 0.9

# %%
print(tp, tn, fp, fn)
# Out:
# 9 49 1 1
